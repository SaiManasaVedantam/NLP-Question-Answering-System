# %%
# Turn off unnecessary warnings
import warnings
warnings.filterwarnings("ignore")

# Import all the required packages
import nltk
import codecs
import urllib
import os, spacy
import en_core_web_sm
#from spacy import displacy
from nltk.corpus import wordnet as wn
from nltk.stem import WordNetLemmatizer
from IPython.core.display import display, HTML
from nltk.tokenize import word_tokenize, sent_tokenize 
nltk.download('punkt')
nltk.download('wordnet')
nlp = en_core_web_sm.load()
from nltk.parse import CoreNLPParser
from nltk.parse.corenlp import CoreNLPDependencyParser


# Helper method to append values to duplicate keys in the dictionaries without data loss
def AppendData(mainDictionary, smallDictionary):
    smallKeys = smallDictionary.keys()
    mainKeys = mainDictionary.keys()
    for key in smallKeys:
        if key in mainKeys:
            mainDictionary[key].append(smallDictionary[key])
        else:
            mainDictionary[key] = smallDictionary[key]
    return mainDictionary
            

# Performs Word tokenization on sentences
def Tokenization(sentence):
    tokens = nltk.word_tokenize(sentence)
    return tokens


# Performs Word Lemmatization
def Lemmatization(word_tokens):
    lemmas = []
    for token in word_tokens:
        lemmas.append(wordnet_lemmatizer.lemmatize(token))
    return lemmas


# Performs POS tagging
def POSTagging(word_tokens):
    POStags = nltk.pos_tag(word_tokens)
    return POStags   


# Obtains sentence heads
def getHeads(sentence, word_tokens):
    dependencyParser = CoreNLPDependencyParser(url='http://localhost:9000')
    headList = []
    stripedSen = sentence.strip(" '\"")
    if stripedSen != "":
        depParse = dependencyParser.raw_parse(stripedSen)
        parseTree = list(depParse)[0]
        headWord = ""
        headWord = [k["word"] for k in parseTree.nodes.values() if k["head"] == 0][0]
        
        if headWord != "":
            headList.append([headWord])
        else:
            for i, pp in enumerate(tagged):
                if pp.startswith("VB"):
                    headList.append([word_tokens[i]])
                    break
            if headWord == "":
                for i, pp in enumerate(tagged):
                    if pp.startswith("NN"):
                        headList.append([word_tokens[i]])
                        break
    else:
        headList.append([""])
 
    return headList


# Obtains WordNet Features
def WordNetFeatures(word_tokens):
    # Creates dictionaries for important word senses
    hypernyms_dict = dict()
    hyponyms_dict = dict()
    meronyms_dict = dict()
    holonyms_dict = dict()
    
    # Populates the above dictionaries according to the word senses associated with them
    for token in word_tokens:
        # For each token, we create & populate the considered word senses & add that to their dictionaries
        token_hypernyms = []
        token_hyponyms = []
        token_meronyms = []
        token_holonyms = []
        
        # Obtain Synsets associated with the token
        synsetList = wn.synsets(token)
        synsetLen = len(synsetList)
        
        if synsetLen != 0:
            for each_syn in synsetList:
                # Appends Hypernym Lemmas to the Hypernym list
                for hypernym in each_syn.hypernyms():
                    for lemma in hypernym.lemmas():
                        token_hypernyms.append(lemma.name())
                
                # Appends Hyponym Lemmas to the Hypernym list
                for hyponym in each_syn.hyponyms():
                    for lemma in hyponym.lemmas():
                        token_hyponyms.append(lemma.name())
                
                # Appends Meronym Lemmas to the Hypernym list
                for meronym in each_syn.part_meronyms():
                    for lemma in meronym.lemmas():
                        token_meronyms.append(lemma.name())
                        
                # Appends Holonym Lemmas to the Hypernym list
                for holonym in each_syn.part_holonyms():
                    for lemma in holonym.lemmas():
                        token_holonyms.append(lemma.name())
                        
        hypernyms_dict[token] = token_hypernyms
        hyponyms_dict[token] = token_hyponyms
        meronyms_dict[token] = token_meronyms
        holonyms_dict[token] = token_holonyms
        
    return hypernyms_dict, hyponyms_dict, meronyms_dict, holonyms_dict
   
    
# Performs Dependency Parsing
def DependencyParsing(sentence):
    dependencyParser = CoreNLPDependencyParser(url='http://localhost:9000')
    parse, = dependencyParser.raw_parse(sentence)
    
    # Dependency parsing to parse tree based patters as features
    depParseResult = list(parse.triples())
    
    return depParseResult
    
    """depedencyParse = nlp(sentence)
    for token in depedencyParse:
        print(token.text,"----->",token.dep_,"----->",token.pos_,)
    print('\n\n')
    display(depedencyParse)
    html = displacy.render(depedencyParse, style="dep")
    display(HTML(html))"""
    

# Main method
if __name__ == "__main__":
    # List of all article names in the repository
    articleNames = ["109.txt"] #,"111.txt", "151.txt", "160.txt", "177.txt", 
                    #"179.txt","181.txt", "196.txt", "199.txt", "220.txt", 
                    #"222.txt", "226.txt", "288.txt", "297.txt", "304.txt", 
                    #"342.txt", "347.txt", "360.txt", "390.txt", "400.txt", 
                    #"56.txt", "58.txt", "6.txt"] 
    fileCount = len(articleNames)
    
    content = ""
    folderPath = "https://raw.githubusercontent.com/SaiManasaVedantam/NLP-QA-System-Datasets/main/Articles/"
    for i in range(fileCount):
        fileName = folderPath + articleNames[i]
        response = urllib.request.urlopen(fileName)
        webContents = response.read()
        stringTypeData = webContents.decode("utf-8")
        content += stringTypeData
        count = 0
        corpus_dict = {}
   
    # Use this if you want to use a local file on your machine
    """
    content = None
    try:
        f = open("Articles/6.txt", "r")
        content = f.read()
        
    except UnicodeDecodeError:
        f = open("Articles/6.txt", "r", encoding = "utf8")
        content = f.read()
        
    """
    
    # Obtain wordnet lemmatizer
    wordnet_lemmatizer = WordNetLemmatizer()
    
    # Get tokenized content
    sentences = []
    tokenizer = nltk.data.load("tokenizers/punkt/english.pickle")
    sentences.extend(tokenizer.tokenize(content))
    
    # Sentence count
    print("Total Sentences After splitting the document: ", len(sentences))
    print("Extracting features for each of the sentences and shown below:")
    
    # We maintain all tokens, lemmas etc. in the following lists
    all_word_tokens = []
    all_word_lemmas = []
    all_word_POStags = []
    all_hypernyms = dict()
    all_hyponymns = dict()
    all_meronyms = dict()
    all_holonyms = dict()
    
    
    # Extracting words
    for sen in sentences:
        print("\n------SENTENCE------")
        print(sen)
        
        print("\n----Word Tokenization----")
        word_tokens = Tokenization(sen)
        all_word_tokens += word_tokens
        #print(word_tokens)
        
        print("\n----Word Lemmatization----")
        word_lemmas = Lemmatization(word_tokens)
        all_word_lemmas += word_lemmas
        #print(word_lemmas)
        
        print("\n----POS Tagging----")
        word_POStags = POSTagging(word_tokens)
        all_word_POStags += word_POStags
        #print(word_POStags)
        
        print("\n----WordNet Feature Extraction----")
        hypernyms, hyponyms, meronyms, holonyms = WordNetFeatures(word_tokens)
        all_hypernyms = AppendData(all_hypernyms, hypernyms)
        #all_hypernyms.update(hypernyms)
        #print("===> HYPERNYMS: <===\n", hypernyms, "\n")
        
        all_hyponymns = AppendData(all_hyponymns, hyponyms)
        #print("===> HYPONYMS: <===\n", hyponyms, "\n")
        
        all_meronyms = AppendData(all_meronyms, meronyms)
        #print("===> MERONYMS: <===\n", meronyms, "\n")
        
        all_holonyms = AppendData(all_holonyms, holonyms)
        #print("===> HOLONYMS: <===\n", holonyms)
        
        print("\n----Dependency Parsing----")
        depParse = DependencyParsing(sen)
        print(depParse)
        
        print("\n----Obtaining Heads----")
        headList = getHeads(sen, word_tokens)
        print(headList)
        
        # Process data format to suit the Elastic Search requirements
        count = count + 1
        corpus_dict[count] = {}
        corpus_dict[count]["sentence"] = {}
        corpus_dict[count]["sentence"] = sen
        corpus_dict[count]["tokenized_text"] = {}
        corpus_dict[count]["tokenized_text"] = word_tokens
        corpus_dict[count]["lemma"] = {}
        corpus_dict[count]["lemma"] = word_lemmas
        #corpus_dict[count]["stemmed"] = {}
        #corpus_dict[count]["stemmed"] = stemmed
        corpus_dict[count]["tagged"] = {}
        corpus_dict[count]["tagged"] = word_POStags
        corpus_dict[count]["dependency_parse"] = {}
        corpus_dict[count]["dependency_parse"] = depParse
        #corpus_dict[count]["synonyms"] = {}
        #corpus_dict[count]["synonyms"] = synonyms
        corpus_dict[count]["hypernyms"] = {}
        corpus_dict[count]["hypernyms"] = hypernyms
        corpus_dict[count]["hyponyms"] = {}
        corpus_dict[count]["hyponyms"] = hyponyms
        corpus_dict[count]["meronyms"] = {}
        corpus_dict[count]["meronyms"] = meronyms
        corpus_dict[count]["holonyms"] = {}
        corpus_dict[count]["holonyms"] = holonyms
        #corpus_dict[count]["ner_tag"] = {}
        #corpus_dict[count]["ner_tag"] = str(dict(ner_tag))
        corpus_dict[count]["head_word"] = {}
        corpus_dict[count]["head_word"] = headList[0]
        corpus_dict[count]["file_name"] = {}
        corpus_dict[count]["file_name"] = articleNames[i]

    output_name = 'pipeline/parsed-' + articleNames[i]
    with open(output_name, 'w', encoding='utf8') as output_file:
        json.dump(corpus_dict, output_file,  indent=4, sort_keys=True, separators=(',', ': '), ensure_ascii=False)
# Out:
# [nltk_data] Downloading package punkt to /Users/Manasa/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/Manasa/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Total Sentences After splitting the document:  204
# Extracting features for each of the sentences and shown below:
#
# ------SENTENCE------
# Bird migration is the regular seasonal movement, often north and south along a flyway, between breeding and wintering grounds.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('movement', 'NN'), 'nsubj', ('migration', 'NN')), (('migration', 'NN'), 'compound', ('Bird', 'NN')), (('movement', 'NN'), 'cop', ('is', 'VBZ')), (('movement', 'NN'), 'det', ('the', 'DT')), (('movement', 'NN'), 'amod', ('regular', 'JJ')), (('movement', 'NN'), 'amod', ('seasonal', 'JJ')), (('movement', 'NN'), 'punct', (',', ',')), (('movement', 'NN'), 'advmod', ('north', 'RB')), (('north', 'RB'), 'advmod', ('often', 'RB')), (('north', 'RB'), 'conj', ('south', 'RB')), (('south', 'RB'), 'cc', ('and', 'CC')), (('north', 'RB'), 'obl', ('flyway', 'NN')), (('flyway', 'NN'), 'case', ('along', 'IN')), (('flyway', 'NN'), 'det', ('a', 'DT')), (('movement', 'NN'), 'punct', (',', ',')), (('movement', 'NN'), 'nmod', ('grounds', 'NNS')), (('grounds', 'NNS'), 'case', ('between', 'IN')), (('grounds', 'NNS'), 'amod', ('breeding', 'VBG')), (('breeding', 'VBG'), 'conj', ('wintering', 'VBG')), (('wintering', 'VBG'), 'cc', ('and', 'CC')), (('movement', 'NN'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['movement']]
#
# ------SENTENCE------
# Many species of bird migrate.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('migrate', 'VBP'), 'nsubj', ('species', 'NNS')), (('species', 'NNS'), 'amod', ('Many', 'JJ')), (('species', 'NNS'), 'nmod', ('bird', 'NN')), (('bird', 'NN'), 'case', ('of', 'IN')), (('migrate', 'VBP'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['migrate']]
#
# ------SENTENCE------
# Migration carries high costs in predation and mortality, including from hunting by humans, and is driven primarily by availability of food.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('carries', 'VBZ'), 'nsubj', ('Migration', 'NNP')), (('carries', 'VBZ'), 'obj', ('costs', 'NNS')), (('costs', 'NNS'), 'amod', ('high', 'JJ')), (('costs', 'NNS'), 'nmod', ('predation', 'NN')), (('predation', 'NN'), 'case', ('in', 'IN')), (('predation', 'NN'), 'conj', ('mortality', 'NN')), (('mortality', 'NN'), 'cc', ('and', 'CC')), (('costs', 'NNS'), 'punct', (',', ',')), (('costs', 'NNS'), 'nmod', ('hunting', 'VBG')), (('hunting', 'VBG'), 'case', ('including', 'VBG')), (('hunting', 'VBG'), 'case', ('from', 'IN')), (('hunting', 'VBG'), 'obl', ('humans', 'NNS')), (('humans', 'NNS'), 'case', ('by', 'IN')), (('hunting', 'VBG'), 'punct', (',', ',')), (('hunting', 'VBG'), 'conj', ('driven', 'VBN')), (('driven', 'VBN'), 'cc', ('and', 'CC')), (('driven', 'VBN'), 'aux:pass', ('is', 'VBZ')), (('driven', 'VBN'), 'advmod', ('primarily', 'RB')), (('driven', 'VBN'), 'obl', ('availability', 'NN')), (('availability', 'NN'), 'case', ('by', 'IN')), (('availability', 'NN'), 'nmod', ('food', 'NN')), (('food', 'NN'), 'case', ('of', 'IN')), (('carries', 'VBZ'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['carries']]
#
# ------SENTENCE------
# It occurs mainly in the northern hemisphere, where birds are funnelled on to specific routes by natural barriers such as the Mediterranean Sea or the Caribbean Sea.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('occurs', 'VBZ'), 'nsubj', ('It', 'PRP')), (('occurs', 'VBZ'), 'advmod', ('mainly', 'RB')), (('occurs', 'VBZ'), 'obl', ('hemisphere', 'NN')), (('hemisphere', 'NN'), 'case', ('in', 'IN')), (('hemisphere', 'NN'), 'det', ('the', 'DT')), (('hemisphere', 'NN'), 'amod', ('northern', 'JJ')), (('hemisphere', 'NN'), 'punct', (',', ',')), (('hemisphere', 'NN'), 'acl:relcl', ('funnelled', 'VBN')), (('funnelled', 'VBN'), 'advmod', ('where', 'WRB')), (('funnelled', 'VBN'), 'nsubj:pass', ('birds', 'NNS')), (('funnelled', 'VBN'), 'aux:pass', ('are', 'VBP')), (('funnelled', 'VBN'), 'compound:prt', ('on', 'IN')), (('funnelled', 'VBN'), 'obl', ('routes', 'NNS')), (('routes', 'NNS'), 'case', ('to', 'IN')), (('routes', 'NNS'), 'amod', ('specific', 'JJ')), (('funnelled', 'VBN'), 'obl', ('barriers', 'NNS')), (('barriers', 'NNS'), 'case', ('by', 'IN')), (('barriers', 'NNS'), 'amod', ('natural', 'JJ')), (('barriers', 'NNS'), 'nmod', ('Sea', 'NNP')), (('Sea', 'NNP'), 'case', ('such', 'JJ')), (('such', 'JJ'), 'fixed', ('as', 'IN')), (('Sea', 'NNP'), 'det', ('the', 'DT')), (('Sea', 'NNP'), 'compound', ('Mediterranean', 'NNP')), (('Sea', 'NNP'), 'conj', ('Sea', 'NNP')), (('Sea', 'NNP'), 'cc', ('or', 'CC')), (('Sea', 'NNP'), 'det', ('the', 'DT')), (('Sea', 'NNP'), 'compound', ('Caribbean', 'NNP')), (('occurs', 'VBZ'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['occurs']]
#
# ------SENTENCE------
# Historically, migration has been recorded as much as 3,000 years ago by Ancient Greek authors including Homer and Aristotle, and in the Book of Job, for species such as storks, turtle doves, and swallows.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('recorded', 'VBN'), 'advmod', ('Historically', 'RB')), (('recorded', 'VBN'), 'punct', (',', ',')), (('recorded', 'VBN'), 'nsubj:pass', ('migration', 'NN')), (('recorded', 'VBN'), 'aux', ('has', 'VBZ')), (('recorded', 'VBN'), 'aux:pass', ('been', 'VBN')), (('recorded', 'VBN'), 'obl', ('years', 'NNS')), (('years', 'NNS'), 'nummod', ('3,000', 'CD')), (('3,000', 'CD'), 'advmod', ('as', 'RB')), (('3,000', 'CD'), 'advmod', ('much', 'RB')), (('3,000', 'CD'), 'advmod', ('as', 'IN')), (('years', 'NNS'), 'case', ('ago', 'IN')), (('recorded', 'VBN'), 'obl', ('authors', 'NNS')), (('authors', 'NNS'), 'case', ('by', 'IN')), (('authors', 'NNS'), 'amod', ('Ancient', 'JJ')), (('authors', 'NNS'), 'amod', ('Greek', 'JJ')), (('authors', 'NNS'), 'nmod', ('Homer', 'NNP')), (('Homer', 'NNP'), 'case', ('including', 'VBG')), (('Homer', 'NNP'), 'conj', ('Aristotle', 'NNP')), (('Aristotle', 'NNP'), 'cc', ('and', 'CC')), (('recorded', 'VBN'), 'punct', (',', ',')), (('recorded', 'VBN'), 'dep', ('and', 'CC')), (('and', 'CC'), 'obl', ('Book', 'NNP')), (('Book', 'NNP'), 'case', ('in', 'IN')), (('Book', 'NNP'), 'det', ('the', 'DT')), (('Book', 'NNP'), 'nmod', ('Job', 'NNP')), (('Job', 'NNP'), 'case', ('of', 'IN')), (('Book', 'NNP'), 'punct', (',', ',')), ((',', ','), 'dep', ('species', 'NNS')), (('species', 'NNS'), 'case', ('for', 'IN')), (('species', 'NNS'), 'nmod', ('storks', 'NNS')), (('storks', 'NNS'), 'case', ('such', 'JJ')), (('such', 'JJ'), 'fixed', ('as', 'IN')), (('storks', 'NNS'), 'punct', (',', ',')), (('storks', 'NNS'), 'conj', ('doves', 'NNS')), (('doves', 'NNS'), 'compound', ('turtle', 'NN')), (('storks', 'NNS'), 'punct', (',', ',')), (('storks', 'NNS'), 'conj', ('swallows', 'NNS')), (('swallows', 'NNS'), 'cc', ('and', 'CC')), (('species', 'NNS'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['recorded']]
#
# ------SENTENCE------
# More recently, Johannes Leche began recording dates of arrivals of spring migrants in Finland in 1749, and scientific studies have used techniques including bird ringing and satellite tracking.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('began', 'VBD'), 'advmod', ('recently', 'RB')), (('recently', 'RB'), 'advmod', ('More', 'RBR')), (('began', 'VBD'), 'punct', (',', ',')), (('began', 'VBD'), 'nsubj', ('Leche', 'NNP')), (('Leche', 'NNP'), 'compound', ('Johannes', 'NNP')), (('began', 'VBD'), 'obj', ('dates', 'NNS')), (('dates', 'NNS'), 'amod', ('recording', 'VBG')), (('dates', 'NNS'), 'nmod', ('arrivals', 'NNS')), (('arrivals', 'NNS'), 'case', ('of', 'IN')), (('arrivals', 'NNS'), 'nmod', ('migrants', 'NNS')), (('migrants', 'NNS'), 'case', ('of', 'IN')), (('migrants', 'NNS'), 'compound', ('spring', 'NN')), (('arrivals', 'NNS'), 'nmod', ('Finland', 'NNP')), (('Finland', 'NNP'), 'case', ('in', 'IN')), (('began', 'VBD'), 'obl', ('1749', 'CD')), (('1749', 'CD'), 'case', ('in', 'IN')), (('began', 'VBD'), 'punct', (',', ',')), (('began', 'VBD'), 'conj', ('used', 'VBN')), (('used', 'VBN'), 'cc', ('and', 'CC')), (('used', 'VBN'), 'nsubj', ('studies', 'NNS')), (('studies', 'NNS'), 'amod', ('scientific', 'JJ')), (('used', 'VBN'), 'aux', ('have', 'VBP')), (('used', 'VBN'), 'obj', ('techniques', 'NNS')), (('techniques', 'NNS'), 'nmod', ('bird', 'NN')), (('bird', 'NN'), 'case', ('including', 'VBG')), (('bird', 'NN'), 'dep', ('ringing', 'VBG')), (('ringing', 'VBG'), 'conj', ('tracking', 'NN')), (('tracking', 'NN'), 'cc', ('and', 'CC')), (('tracking', 'NN'), 'compound', ('satellite', 'NN')), (('began', 'VBD'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['began']]
#
# ------SENTENCE------
# Threats to migratory birds have grown with habitat destruction especially of stopover and wintering sites, as well as structures such as power lines and wind farms.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('grown', 'VBN'), 'nsubj', ('Threats', 'NNS')), (('Threats', 'NNS'), 'nmod', ('birds', 'NNS')), (('birds', 'NNS'), 'case', ('to', 'IN')), (('birds', 'NNS'), 'amod', ('migratory', 'JJ')), (('grown', 'VBN'), 'aux', ('have', 'VBP')), (('grown', 'VBN'), 'obl', ('destruction', 'NN')), (('destruction', 'NN'), 'case', ('with', 'IN')), (('destruction', 'NN'), 'compound', ('habitat', 'NN')), (('destruction', 'NN'), 'nmod', ('stopover', 'NN')), (('stopover', 'NN'), 'advmod', ('especially', 'RB')), (('stopover', 'NN'), 'case', ('of', 'IN')), (('stopover', 'NN'), 'conj', ('wintering', 'VBG')), (('wintering', 'VBG'), 'cc', ('and', 'CC')), (('stopover', 'NN'), 'obj', ('sites', 'NNS')), (('sites', 'NNS'), 'punct', (',', ',')), (('sites', 'NNS'), 'conj', ('structures', 'NNS')), (('structures', 'NNS'), 'cc', ('as', 'RB')), (('as', 'RB'), 'fixed', ('well', 'RB')), (('as', 'RB'), 'fixed', ('as', 'IN')), (('structures', 'NNS'), 'nmod', ('lines', 'NNS')), (('lines', 'NNS'), 'case', ('such', 'JJ')), (('such', 'JJ'), 'fixed', ('as', 'IN')), (('lines', 'NNS'), 'compound', ('power', 'NN')), (('lines', 'NNS'), 'conj', ('farms', 'NNS')), (('farms', 'NNS'), 'cc', ('and', 'CC')), (('farms', 'NNS'), 'compound', ('wind', 'NN')), (('grown', 'VBN'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['grown']]
#
# ------SENTENCE------
# The Arctic tern holds the long-distance migration record for birds, travelling between Arctic breeding grounds and the Antarctic each year.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('holds', 'VBZ'), 'nsubj', ('tern', 'NN')), (('tern', 'NN'), 'det', ('The', 'DT')), (('tern', 'NN'), 'compound', ('Arctic', 'NNP')), (('holds', 'VBZ'), 'obj', ('record', 'NN')), (('record', 'NN'), 'det', ('the', 'DT')), (('record', 'NN'), 'compound', ('distance', 'NN')), (('distance', 'NN'), 'amod', ('long', 'JJ')), (('distance', 'NN'), 'punct', ('-', 'HYPH')), (('record', 'NN'), 'compound', ('migration', 'NN')), (('record', 'NN'), 'nmod', ('birds', 'NNS')), (('birds', 'NNS'), 'case', ('for', 'IN')), (('birds', 'NNS'), 'punct', (',', ',')), (('birds', 'NNS'), 'acl', ('travelling', 'VBG')), (('travelling', 'VBG'), 'obl', ('grounds', 'NNS')), (('grounds', 'NNS'), 'case', ('between', 'IN')), (('grounds', 'NNS'), 'compound', ('Arctic', 'NNP')), (('grounds', 'NNS'), 'amod', ('breeding', 'VBG')), (('grounds', 'NNS'), 'conj', ('Antarctic', 'NNP')), (('Antarctic', 'NNP'), 'cc', ('and', 'CC')), (('Antarctic', 'NNP'), 'det', ('the', 'DT')), (('travelling', 'VBG'), 'obl:tmod', ('year', 'NN')), (('year', 'NN'), 'det', ('each', 'DT')), (('holds', 'VBZ'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['holds']]
#
# ------SENTENCE------
# Some species of tubenoses (Procellariiformes) such as albatrosses circle the earth, flying over the southern oceans, while others such as Manx shearwaters migrate 14,000 km (8,700 mi) between their northern breeding grounds and the southern ocean.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('species', 'NNS'), 'det', ('Some', 'DT')), (('species', 'NNS'), 'nmod', ('tubenoses', 'NNS')), (('tubenoses', 'NNS'), 'case', ('of', 'IN')), (('tubenoses', 'NNS'), 'punct', ('(', '-LRB-')), (('tubenoses', 'NNS'), 'dep', ('Procellariiformes', 'NNP')), (('tubenoses', 'NNS'), 'punct', (')', '-RRB-')), (('tubenoses', 'NNS'), 'nmod', ('albatrosses', 'NNS')), (('albatrosses', 'NNS'), 'case', ('such', 'JJ')), (('such', 'JJ'), 'fixed', ('as', 'IN')), (('albatrosses', 'NNS'), 'acl', ('circle', 'VBP')), (('circle', 'VBP'), 'obj', ('earth', 'NN')), (('earth', 'NN'), 'det', ('the', 'DT')), (('species', 'NNS'), 'punct', (',', ',')), (('species', 'NNS'), 'acl', ('flying', 'VBG')), (('flying', 'VBG'), 'obl', ('oceans', 'NNS')), (('oceans', 'NNS'), 'case', ('over', 'IN')), (('oceans', 'NNS'), 'det', ('the', 'DT')), (('oceans', 'NNS'), 'amod', ('southern', 'JJ')), (('species', 'NNS'), 'punct', (',', ',')), (('species', 'NNS'), 'dep', ('migrate', 'VBP')), (('migrate', 'VBP'), 'mark', ('while', 'IN')), (('migrate', 'VBP'), 'nsubj', ('others', 'NNS')), (('others', 'NNS'), 'nmod', ('shearwaters', 'NNS')), (('shearwaters', 'NNS'), 'case', ('such', 'JJ')), (('such', 'JJ'), 'fixed', ('as', 'IN')), (('shearwaters', 'NNS'), 'compound', ('Manx', 'NNP')), (('migrate', 'VBP'), 'obj', ('km', 'NNS')), (('km', 'NNS'), 'nummod', ('14,000', 'CD')), (('km', 'NNS'), 'appos', ('mi', 'NNP')), (('mi', 'NNP'), 'punct', ('(', '-LRB-')), (('mi', 'NNP'), 'nummod', ('8,700', 'CD')), (('mi', 'NNP'), 'punct', (')', '-RRB-')), (('km', 'NNS'), 'nmod', ('grounds', 'NNS')), (('grounds', 'NNS'), 'case', ('between', 'IN')), (('grounds', 'NNS'), 'nmod:poss', ('their', 'PRP$')), (('grounds', 'NNS'), 'amod', ('northern', 'JJ')), (('grounds', 'NNS'), 'compound', ('breeding', 'NN')), (('grounds', 'NNS'), 'conj', ('ocean', 'NN')), (('ocean', 'NN'), 'cc', ('and', 'CC')), (('ocean', 'NN'), 'det', ('the', 'DT')), (('ocean', 'NN'), 'amod', ('southern', 'JJ')), (('species', 'NNS'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['species']]
#
# ------SENTENCE------
# Shorter migrations are common, including altitudinal migrations on mountains such as the Andes and Himalayas.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('common', 'JJ'), 'nsubj', ('migrations', 'NNS')), (('migrations', 'NNS'), 'amod', ('Shorter', 'JJR')), (('common', 'JJ'), 'cop', ('are', 'VBP')), (('common', 'JJ'), 'punct', (',', ',')), (('common', 'JJ'), 'obl', ('migrations', 'NNS')), (('migrations', 'NNS'), 'case', ('including', 'VBG')), (('migrations', 'NNS'), 'amod', ('altitudinal', 'JJ')), (('migrations', 'NNS'), 'nmod', ('mountains', 'NNS')), (('mountains', 'NNS'), 'case', ('on', 'IN')), (('mountains', 'NNS'), 'nmod', ('Andes', 'NNP')), (('Andes', 'NNP'), 'case', ('such', 'JJ')), (('such', 'JJ'), 'fixed', ('as', 'IN')), (('Andes', 'NNP'), 'det', ('the', 'DT')), (('Andes', 'NNP'), 'conj', ('Himalayas', 'NNP')), (('Himalayas', 'NNP'), 'cc', ('and', 'CC')), (('common', 'JJ'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['common']]
#
# ------SENTENCE------
# The timing of migration seems to be controlled primarily by changes in day length.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('seems', 'VBZ'), 'nsubj', ('timing', 'NN')), (('timing', 'NN'), 'det', ('The', 'DT')), (('timing', 'NN'), 'nmod', ('migration', 'NN')), (('migration', 'NN'), 'case', ('of', 'IN')), (('seems', 'VBZ'), 'xcomp', ('controlled', 'VBN')), (('controlled', 'VBN'), 'mark', ('to', 'TO')), (('controlled', 'VBN'), 'aux:pass', ('be', 'VB')), (('controlled', 'VBN'), 'advmod', ('primarily', 'RB')), (('controlled', 'VBN'), 'obl', ('changes', 'NNS')), (('changes', 'NNS'), 'case', ('by', 'IN')), (('changes', 'NNS'), 'nmod', ('length', 'NN')), (('length', 'NN'), 'case', ('in', 'IN')), (('length', 'NN'), 'compound', ('day', 'NN')), (('seems', 'VBZ'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['seems']]
#
# ------SENTENCE------
# Migrating birds navigate using celestial cues from the sun and stars, the earth's magnetic field, and probably also mental maps.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('navigate', 'VBP'), 'nsubj', ('birds', 'NNS')), (('birds', 'NNS'), 'amod', ('Migrating', 'VBG')), (('navigate', 'VBP'), 'obj', ('using', 'VBG')), (('using', 'VBG'), 'obj', ('cues', 'NNS')), (('cues', 'NNS'), 'amod', ('celestial', 'JJ')), (('using', 'VBG'), 'obl', ('sun', 'NN')), (('sun', 'NN'), 'case', ('from', 'IN')), (('sun', 'NN'), 'det', ('the', 'DT')), (('sun', 'NN'), 'conj', ('stars', 'NNS')), (('stars', 'NNS'), 'cc', ('and', 'CC')), (('using', 'VBG'), 'punct', (',', ',')), (('using', 'VBG'), 'obj', ('field', 'NN')), (('field', 'NN'), 'nmod:poss', ('earth', 'NN')), (('earth', 'NN'), 'det', ('the', 'DT')), (('earth', 'NN'), 'case', ("'s", 'POS')), (('field', 'NN'), 'amod', ('magnetic', 'JJ')), (('using', 'VBG'), 'punct', (',', ',')), (('using', 'VBG'), 'conj', ('maps', 'NNS')), (('maps', 'NNS'), 'cc', ('and', 'CC')), (('maps', 'NNS'), 'advmod', ('probably', 'RB')), (('maps', 'NNS'), 'advmod', ('also', 'RB')), (('maps', 'NNS'), 'amod', ('mental', 'JJ')), (('navigate', 'VBP'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['navigate']]
#
# ------SENTENCE------
# Records of bird migration were made as much as 3,000 years ago by the Ancient Greek writers Hesiod, Homer, Herodotus and Aristotle.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('made', 'VBN'), 'nsubj:pass', ('Records', 'NNS')), (('Records', 'NNS'), 'nmod', ('migration', 'NN')), (('migration', 'NN'), 'case', ('of', 'IN')), (('migration', 'NN'), 'compound', ('bird', 'NN')), (('made', 'VBN'), 'aux:pass', ('were', 'VBD')), (('made', 'VBN'), 'obl', ('years', 'NNS')), (('years', 'NNS'), 'nummod', ('3,000', 'CD')), (('3,000', 'CD'), 'advmod', ('as', 'RB')), (('3,000', 'CD'), 'advmod', ('much', 'RB')), (('3,000', 'CD'), 'advmod', ('as', 'IN')), (('years', 'NNS'), 'case', ('ago', 'IN')), (('made', 'VBN'), 'obl', ('writers', 'NNS')), (('writers', 'NNS'), 'case', ('by', 'IN')), (('writers', 'NNS'), 'det', ('the', 'DT')), (('writers', 'NNS'), 'amod', ('Ancient', 'JJ')), (('writers', 'NNS'), 'amod', ('Greek', 'JJ')), (('writers', 'NNS'), 'dep', ('Hesiod', 'NNP')), (('Hesiod', 'NNP'), 'punct', (',', ',')), (('Hesiod', 'NNP'), 'conj', ('Homer', 'NNP')), (('Hesiod', 'NNP'), 'punct', (',', ',')), (('Hesiod', 'NNP'), 'conj', ('Herodotus', 'NNP')), (('Hesiod', 'NNP'), 'conj', ('Aristotle', 'NNP')), (('Aristotle', 'NNP'), 'cc', ('and', 'CC')), (('made', 'VBN'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['made']]
#
# ------SENTENCE------
# The Bible also notes migrations, as in the Book of Job (39:26), where the inquiry is made: "Is it by your insight that the hawk hovers, spreads its wings southward?"
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('notes', 'VBZ'), 'nsubj', ('Bible', 'NNP')), (('Bible', 'NNP'), 'det', ('The', 'DT')), (('notes', 'VBZ'), 'advmod', ('also', 'RB')), (('notes', 'VBZ'), 'obj', ('migrations', 'NNS')), (('notes', 'VBZ'), 'punct', (',', ',')), (('notes', 'VBZ'), 'obl', ('Book', 'NNP')), (('Book', 'NNP'), 'case', ('as', 'IN')), (('Book', 'NNP'), 'case', ('in', 'IN')), (('Book', 'NNP'), 'det', ('the', 'DT')), (('Book', 'NNP'), 'nmod', ('Job', 'NNP')), (('Job', 'NNP'), 'case', ('of', 'IN')), (('Book', 'NNP'), 'punct', ('(', '-LRB-')), (('Book', 'NNP'), 'obl:tmod', ('39:26', 'CD')), (('Book', 'NNP'), 'punct', (')', '-RRB-')), (('Book', 'NNP'), 'punct', (',', ',')), (('Book', 'NNP'), 'acl:relcl', ('made', 'VBN')), (('made', 'VBN'), 'advmod', ('where', 'WRB')), (('made', 'VBN'), 'nsubj:pass', ('inquiry', 'NN')), (('inquiry', 'NN'), 'det', ('the', 'DT')), (('made', 'VBN'), 'aux:pass', ('is', 'VBZ')), (('made', 'VBN'), 'punct', (':', ':')), (('made', 'VBN'), 'punct', ('"', '``')), (('made', 'VBN'), 'dep', ('spreads', 'VBZ')), (('spreads', 'VBZ'), 'dep', ('Is', 'VBZ')), (('Is', 'VBZ'), 'nsubj', ('it', 'PRP')), (('spreads', 'VBZ'), 'obl', ('insight', 'NN')), (('insight', 'NN'), 'case', ('by', 'IN')), (('insight', 'NN'), 'nmod:poss', ('your', 'PRP$')), (('insight', 'NN'), 'ccomp', ('hovers', 'VBZ')), (('hovers', 'VBZ'), 'mark', ('that', 'IN')), (('hovers', 'VBZ'), 'nsubj', ('hawk', 'NN')), (('hawk', 'NN'), 'det', ('the', 'DT')), (('spreads', 'VBZ'), 'punct', (',', ',')), (('spreads', 'VBZ'), 'obj', ('wings', 'NNS')), (('wings', 'NNS'), 'nmod:poss', ('its', 'PRP$')), (('spreads', 'VBZ'), 'advmod', ('southward', 'RB')), (('notes', 'VBZ'), 'punct', ('?', '.')), (('notes', 'VBZ'), 'punct', ('"', "''"))]
#
# ----Obtaining Heads----
# [['notes']]
#
# ------SENTENCE------
# The author of Jeremiah (8:7) wrote: "Even the stork in the heavens knows its seasons, and the turtle dove, the swift and the crane keep the time of their arrival."
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
# ----Dependency Parsing----
# [(('wrote', 'VBD'), 'nsubj', ('author', 'NN')), (('author', 'NN'), 'det', ('The', 'DT')), (('author', 'NN'), 'nmod', ('Jeremiah', 'NNP')), (('Jeremiah', 'NNP'), 'case', ('of', 'IN')), (('Jeremiah', 'NNP'), 'punct', ('(', '-LRB-')), (('Jeremiah', 'NNP'), 'dep', ('8:7', 'CD')), (('Jeremiah', 'NNP'), 'punct', (')', '-RRB-')), (('wrote', 'VBD'), 'punct', (':', ':')), (('wrote', 'VBD'), 'punct', ('"', '``')), (('wrote', 'VBD'), 'ccomp', ('knows', 'VBZ')), (('knows', 'VBZ'), 'nsubj', ('stork', 'NN')), (('stork', 'NN'), 'advmod', ('Even', 'RB')), (('stork', 'NN'), 'det', ('the', 'DT')), (('stork', 'NN'), 'nmod', ('heavens', 'NNPS')), (('heavens', 'NNPS'), 'case', ('in', 'IN')), (('heavens', 'NNPS'), 'det', ('the', 'DT')), (('knows', 'VBZ'), 'obj', ('seasons', 'NNS')), (('seasons', 'NNS'), 'nmod:poss', ('its', 'PRP$')), (('knows', 'VBZ'), 'punct', (',', ',')), (('knows', 'VBZ'), 'conj', ('keep', 'VB')), (('keep', 'VB'), 'cc', ('and', 'CC')), (('keep', 'VB'), 'nsubj', ('dove', 'NN')), (('dove', 'NN'), 'det', ('the', 'DT')), (('dove', 'NN'), 'compound', ('turtle', 'NN')), (('dove', 'NN'), 'punct', (',', ',')), (('dove', 'NN'), 'conj', ('swift', 'JJ')), (('swift', 'JJ'), 'det', ('the', 'DT')), (('dove', 'NN'), 'conj', ('crane', 'NN')), (('crane', 'NN'), 'cc', ('and', 'CC')), (('crane', 'NN'), 'det', ('the', 'DT')), (('keep', 'VB'), 'obj', ('time', 'NN')), (('time', 'NN'), 'det', ('the', 'DT')), (('time', 'NN'), 'nmod', ('arrival', 'NN')), (('arrival', 'NN'), 'case', ('of', 'IN')), (('arrival', 'NN'), 'nmod:poss', ('their', 'PRP$')), (('wrote', 'VBD'), 'punct', ('.', '.')), (('wrote', 'VBD'), 'punct', ('"', "''"))]
#
# ----Obtaining Heads----
# [['wrote']]
#
# ------SENTENCE------
# Aristotle noted that cranes traveled from the steppes of Scythia to marshes at the headwaters of the Nile.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('noted', 'VBD'), 'nsubj', ('Aristotle', 'NNP')), (('noted', 'VBD'), 'ccomp', ('traveled', 'VBN')), (('traveled', 'VBN'), 'mark', ('that', 'IN')), (('traveled', 'VBN'), 'nsubj', ('cranes', 'NNS')), (('traveled', 'VBN'), 'obl', ('steppes', 'NNS')), (('steppes', 'NNS'), 'case', ('from', 'IN')), (('steppes', 'NNS'), 'det', ('the', 'DT')), (('steppes', 'NNS'), 'nmod', ('Scythia', 'NNP')), (('Scythia', 'NNP'), 'case', ('of', 'IN')), (('traveled', 'VBN'), 'obl', ('marshes', 'NNS')), (('marshes', 'NNS'), 'case', ('to', 'IN')), (('marshes', 'NNS'), 'nmod', ('headwaters', 'NNS')), (('headwaters', 'NNS'), 'case', ('at', 'IN')), (('headwaters', 'NNS'), 'det', ('the', 'DT')), (('headwaters', 'NNS'), 'nmod', ('Nile', 'NNP')), (('Nile', 'NNP'), 'case', ('of', 'IN')), (('Nile', 'NNP'), 'det', ('the', 'DT')), (('noted', 'VBD'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['noted']]
#
# ------SENTENCE------
# Pliny the Elder, in his Historia Naturalis, repeats Aristotle's observations.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('Pliny', 'NNP'), 'dep', ('Elder', 'NN')), (('Elder', 'NN'), 'det', ('the', 'DT')), (('Pliny', 'NNP'), 'punct', (',', ',')), (('Pliny', 'NNP'), 'obl', ('Naturalis', 'NNP')), (('Naturalis', 'NNP'), 'case', ('in', 'IN')), (('Naturalis', 'NNP'), 'nmod:poss', ('his', 'PRP$')), (('Naturalis', 'NNP'), 'compound', ('Historia', 'NNP')), (('Naturalis', 'NNP'), 'punct', (',', ',')), (('Naturalis', 'NNP'), 'appos', ('observations', 'NNS')), (('observations', 'NNS'), 'nmod:poss', ('Aristotle', 'NNP')), (('Aristotle', 'NNP'), 'compound', ('repeats', 'NNS')), (('Aristotle', 'NNP'), 'case', ("'s", 'POS')), (('Pliny', 'NNP'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['Pliny']]
#
# ------SENTENCE------
# Aristotle however suggested that swallows and other birds hibernated.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('suggested', 'VBD'), 'nsubj', ('Aristotle', 'NNP')), (('suggested', 'VBD'), 'advmod', ('however', 'RB')), (('suggested', 'VBD'), 'ccomp', ('hibernated', 'VBD')), (('hibernated', 'VBD'), 'mark', ('that', 'IN')), (('hibernated', 'VBD'), 'nsubj', ('swallows', 'NNS')), (('swallows', 'NNS'), 'conj', ('birds', 'NNS')), (('birds', 'NNS'), 'cc', ('and', 'CC')), (('birds', 'NNS'), 'amod', ('other', 'JJ')), (('suggested', 'VBD'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['suggested']]
#
# ------SENTENCE------
# This belief persisted as late as 1878, when Elliott Coues listed the titles of no less than 182 papers dealing with the hibernation of swallows.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('persisted', 'VBD'), 'nsubj', ('belief', 'NN')), (('belief', 'NN'), 'det', ('This', 'DT')), (('persisted', 'VBD'), 'advcl', ('late', 'JJ')), (('late', 'JJ'), 'case', ('as', 'IN')), (('late', 'JJ'), 'obl', ('1878', 'CD')), (('1878', 'CD'), 'case', ('as', 'IN')), (('late', 'JJ'), 'punct', (',', ',')), (('late', 'JJ'), 'advcl', ('listed', 'VBD')), (('listed', 'VBD'), 'advmod', ('when', 'WRB')), (('listed', 'VBD'), 'nsubj', ('Coues', 'NNP')), (('Coues', 'NNP'), 'compound', ('Elliott', 'NNP')), (('listed', 'VBD'), 'obj', ('titles', 'NNS')), (('titles', 'NNS'), 'det', ('the', 'DT')), (('titles', 'NNS'), 'nmod', ('papers', 'NNS')), (('papers', 'NNS'), 'case', ('of', 'IN')), (('papers', 'NNS'), 'nummod', ('182', 'CD')), (('182', 'CD'), 'advmod', ('no', 'DT')), (('182', 'CD'), 'advmod', ('less', 'JJR')), (('less', 'JJR'), 'fixed', ('than', 'IN')), (('papers', 'NNS'), 'acl', ('dealing', 'VBG')), (('dealing', 'VBG'), 'obl', ('hibernation', 'NN')), (('hibernation', 'NN'), 'case', ('with', 'IN')), (('hibernation', 'NN'), 'det', ('the', 'DT')), (('hibernation', 'NN'), 'nmod', ('swallows', 'NNS')), (('swallows', 'NNS'), 'case', ('of', 'IN')), (('persisted', 'VBD'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['persisted']]
#
# ------SENTENCE------
# Even the "highly observant" Gilbert White, in his posthumously published 1789 The Natural History of Selborne, quoted a man's story about swallows being found in a chalk cliff collapse "while he was a schoolboy at Brighthelmstone", though the man denied being an eyewitness.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('quoted', 'VBD'), 'nsubj', ('White', 'NNP')), (('White', 'NNP'), 'advmod', ('Even', 'RB')), (('White', 'NNP'), 'det', ('the', 'DT')), (('White', 'NNP'), 'punct', ('"', '``')), (('White', 'NNP'), 'amod', ('observant', 'JJ')), (('observant', 'JJ'), 'advmod', ('highly', 'RB')), (('White', 'NNP'), 'punct', ('"', '``')), (('White', 'NNP'), 'compound', ('Gilbert', 'NNP')), (('quoted', 'VBD'), 'punct', (',', ',')), (('quoted', 'VBD'), 'obl', ('History', 'NN')), (('History', 'NN'), 'case', ('in', 'IN')), (('History', 'NN'), 'nmod:poss', ('his', 'PRP$')), (('History', 'NN'), 'amod', ('published', 'VBN')), (('published', 'VBN'), 'advmod', ('posthumously', 'RB')), (('History', 'NN'), 'nummod', ('1789', 'CD')), (('History', 'NN'), 'det', ('The', 'DT')), (('History', 'NN'), 'amod', ('Natural', 'JJ')), (('History', 'NN'), 'nmod', ('Selborne', 'NNP')), (('Selborne', 'NNP'), 'case', ('of', 'IN')), (('quoted', 'VBD'), 'punct', (',', ',')), (('quoted', 'VBD'), 'obj', ('story', 'NN')), (('story', 'NN'), 'nmod:poss', ('man', 'NN')), (('man', 'NN'), 'det', ('a', 'DT')), (('man', 'NN'), 'case', ("'s", 'POS')), (('story', 'NN'), 'nmod', ('swallows', 'NNS')), (('swallows', 'NNS'), 'case', ('about', 'IN')), (('swallows', 'NNS'), 'acl', ('found', 'VBN')), (('found', 'VBN'), 'aux:pass', ('being', 'VBG')), (('found', 'VBN'), 'obl', ('collapse', 'NN')), (('collapse', 'NN'), 'case', ('in', 'IN')), (('collapse', 'NN'), 'det', ('a', 'DT')), (('collapse', 'NN'), 'compound', ('cliff', 'NN')), (('cliff', 'NN'), 'compound', ('chalk', 'NN')), (('quoted', 'VBD'), 'punct', ('"', "''")), (('quoted', 'VBD'), 'advcl', ('schoolboy', 'NN')), (('schoolboy', 'NN'), 'mark', ('while', 'IN')), (('schoolboy', 'NN'), 'nsubj', ('he', 'PRP')), (('schoolboy', 'NN'), 'cop', ('was', 'VBD')), (('schoolboy', 'NN'), 'det', ('a', 'DT')), (('schoolboy', 'NN'), 'obl', ('Brighthelmstone', 'NNP')), (('Brighthelmstone', 'NNP'), 'case', ('at', 'IN')), (('quoted', 'VBD'), 'punct', ('"', "''")), (('quoted', 'VBD'), 'punct', (',', ',')), (('quoted', 'VBD'), 'advcl', ('denied', 'VBD')), (('denied', 'VBD'), 'mark', ('though', 'IN')), (('denied', 'VBD'), 'nsubj', ('man', 'NN')), (('man', 'NN'), 'det', ('the', 'DT')), (('denied', 'VBD'), 'obj', ('eyewitness', 'NN')), (('eyewitness', 'NN'), 'cop', ('being', 'VBG')), (('eyewitness', 'NN'), 'det', ('an', 'DT')), (('quoted', 'VBD'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['quoted']]
#
# ------SENTENCE------
# However, he also writes that "as to swallows being found in a torpid state during the winter in the Isle of Wight or any part of this country, I never heard any such account worth attending to", and that if early swallows "happen to find frost and snow they immediately withdraw for a time—a circumstance this much more in favour of hiding than migration", since he doubts they would "return for a week or two to warmer latitudes".
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('writes', 'VBZ'), 'advmod', ('However', 'RB')), (('writes', 'VBZ'), 'punct', (',', ',')), (('writes', 'VBZ'), 'nsubj', ('he', 'PRP')), (('writes', 'VBZ'), 'advmod', ('also', 'RB')), (('writes', 'VBZ'), 'ccomp', ('heard', 'VBD')), (('heard', 'VBD'), 'mark', ('that', 'IN')), (('heard', 'VBD'), 'punct', ('"', '``')), (('heard', 'VBD'), 'advcl', ('found', 'VBN')), (('found', 'VBN'), 'mark', ('as', 'IN')), (('as', 'IN'), 'fixed', ('to', 'IN')), (('found', 'VBN'), 'nsubj:pass', ('swallows', 'NNS')), (('found', 'VBN'), 'aux:pass', ('being', 'VBG')), (('found', 'VBN'), 'obl', ('state', 'NN')), (('state', 'NN'), 'case', ('in', 'IN')), (('state', 'NN'), 'det', ('a', 'DT')), (('state', 'NN'), 'amod', ('torpid', 'JJ')), (('found', 'VBN'), 'obl', ('winter', 'NN')), (('winter', 'NN'), 'case', ('during', 'IN')), (('winter', 'NN'), 'det', ('the', 'DT')), (('winter', 'NN'), 'nmod', ('Isle', 'NNP')), (('Isle', 'NNP'), 'case', ('in', 'IN')), (('Isle', 'NNP'), 'det', ('the', 'DT')), (('Isle', 'NNP'), 'nmod', ('Wight', 'NNP')), (('Wight', 'NNP'), 'case', ('of', 'IN')), (('winter', 'NN'), 'conj', ('part', 'NN')), (('part', 'NN'), 'cc', ('or', 'CC')), (('part', 'NN'), 'det', ('any', 'DT')), (('part', 'NN'), 'nmod', ('country', 'NN')), (('country', 'NN'), 'case', ('of', 'IN')), (('country', 'NN'), 'det', ('this', 'DT')), (('heard', 'VBD'), 'punct', (',', ',')), (('heard', 'VBD'), 'nsubj', ('I', 'PRP')), (('heard', 'VBD'), 'advmod', ('never', 'RB')), (('heard', 'VBD'), 'obj', ('account', 'NN')), (('account', 'NN'), 'det', ('any', 'DT')), (('account', 'NN'), 'amod', ('such', 'JJ')), (('account', 'NN'), 'amod', ('worth', 'JJ')), (('worth', 'JJ'), 'dep', ('attending', 'VBG')), (('worth', 'JJ'), 'obl', ('circumstance', 'NN')), (('circumstance', 'NN'), 'case', ('to', 'IN')), (('circumstance', 'NN'), 'punct', ('"', '``')), (('circumstance', 'NN'), 'punct', (',', ',')), (('circumstance', 'NN'), 'dep', ('withdraw', 'VB')), (('withdraw', 'VB'), 'cc', ('and', 'CC')), (('withdraw', 'VB'), 'mark', ('that', 'IN')), (('withdraw', 'VB'), 'advcl', ('happen', 'VB')), (('happen', 'VB'), 'mark', ('if', 'IN')), (('happen', 'VB'), 'nsubj', ('swallows', 'NNS')), (('swallows', 'NNS'), 'amod', ('early', 'JJ')), (('happen', 'VB'), 'punct', ('"', "''")), (('happen', 'VB'), 'xcomp', ('find', 'VB')), (('find', 'VB'), 'mark', ('to', 'TO')), (('find', 'VB'), 'obj', ('frost', 'NN')), (('frost', 'NN'), 'conj', ('snow', 'NN')), (('snow', 'NN'), 'cc', ('and', 'CC')), (('withdraw', 'VB'), 'nsubj', ('they', 'PRP')), (('withdraw', 'VB'), 'advmod', ('immediately', 'RB')), (('withdraw', 'VB'), 'obl', ('time', 'NN')), (('time', 'NN'), 'case', ('for', 'IN')), (('time', 'NN'), 'det', ('a', 'DT')), (('circumstance', 'NN'), 'punct', ('—', ',')), (('circumstance', 'NN'), 'det', ('a', 'DT')), (('circumstance', 'NN'), 'dep', ('this', 'DT')), (('this', 'DT'), 'obl', ('favour', 'NN')), (('favour', 'NN'), 'advmod', ('more', 'RBR')), (('more', 'RBR'), 'advmod', ('much', 'RB')), (('favour', 'NN'), 'case', ('in', 'IN')), (('favour', 'NN'), 'nmod', ('hiding', 'NN')), (('hiding', 'NN'), 'case', ('of', 'IN')), (('favour', 'NN'), 'nmod', ('migration', 'NN')), (('migration', 'NN'), 'case', ('than', 'IN')), (('migration', 'NN'), 'punct', ('"', "''")), (('favour', 'NN'), 'punct', (',', ',')), (('favour', 'NN'), 'dep', ('return', 'VB')), (('return', 'VB'), 'advcl', ('doubts', 'VBZ')), (('doubts', 'VBZ'), 'mark', ('since', 'IN')), (('doubts', 'VBZ'), 'nsubj', ('he', 'PRP')), (('return', 'VB'), 'nsubj', ('they', 'PRP')), (('return', 'VB'), 'aux', ('would', 'MD')), (('return', 'VB'), 'punct', ('"', '``')), (('return', 'VB'), 'obl', ('week', 'NN')), (('week', 'NN'), 'case', ('for', 'IN')), (('week', 'NN'), 'det', ('a', 'DT')), (('week', 'NN'), 'nummod', ('two', 'CD')), (('two', 'CD'), 'cc', ('or', 'CC')), (('return', 'VB'), 'obl', ('latitudes', 'NNS')), (('latitudes', 'NNS'), 'case', ('to', 'IN')), (('latitudes', 'NNS'), 'amod', ('warmer', 'JJR')), (('return', 'VB'), 'punct', ('"', "''")), (('writes', 'VBZ'), 'p ...
#
# ----Obtaining Heads----
# [['writes']]
#
# ------SENTENCE------
# It was not until the end of the eighteenth century that migration as an explanation for the winter disappearance of birds from northern climes was accepted.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('end', 'NN'), 'nsubj', ('It', 'PRP')), (('end', 'NN'), 'cop', ('was', 'VBD')), (('end', 'NN'), 'advmod', ('not', 'RB')), (('end', 'NN'), 'case', ('until', 'IN')), (('end', 'NN'), 'det', ('the', 'DT')), (('end', 'NN'), 'nmod', ('century', 'NN')), (('century', 'NN'), 'case', ('of', 'IN')), (('century', 'NN'), 'det', ('the', 'DT')), (('century', 'NN'), 'compound', ('eighteenth', 'NN')), (('end', 'NN'), 'parataxis', ('accepted', 'VBN')), (('accepted', 'VBN'), 'nsubj:pass', ('migration', 'NN')), (('migration', 'NN'), 'det', ('that', 'WDT')), (('migration', 'NN'), 'nmod', ('explanation', 'NN')), (('explanation', 'NN'), 'case', ('as', 'IN')), (('explanation', 'NN'), 'det', ('an', 'DT')), (('explanation', 'NN'), 'nmod', ('disappearance', 'NN')), (('disappearance', 'NN'), 'case', ('for', 'IN')), (('disappearance', 'NN'), 'det', ('the', 'DT')), (('disappearance', 'NN'), 'compound', ('winter', 'NN')), (('disappearance', 'NN'), 'nmod', ('birds', 'NNS')), (('birds', 'NNS'), 'case', ('of', 'IN')), (('birds', 'NNS'), 'nmod', ('climes', 'NNS')), (('climes', 'NNS'), 'case', ('from', 'IN')), (('climes', 'NNS'), 'amod', ('northern', 'JJ')), (('accepted', 'VBN'), 'aux:pass', ('was', 'VBD')), (('end', 'NN'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['end']]
#
# ------SENTENCE------
# Thomas Bewick's A History of British Birds (Volume 1, 1797) mentions a report from "a very intelligent master of a vessel" who, "between the islands of Minorca and Majorca, saw great numbers of Swallows flying northward", and states the situation in Britain as follows: Bewick then describes an experiment which succeeded in keeping swallows alive in Britain for several years, where they remained warm and dry through the winters.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('mentions', 'VBZ'), 'nsubj', ('History', 'NN')), (('History', 'NN'), 'nmod:poss', ('Bewick', 'NNP')), (('Bewick', 'NNP'), 'compound', ('Thomas', 'NNP')), (('Bewick', 'NNP'), 'case', ("'s", 'POS')), (('History', 'NN'), 'det', ('A', 'DT')), (('History', 'NN'), 'nmod', ('Birds', 'NNS')), (('Birds', 'NNS'), 'case', ('of', 'IN')), (('Birds', 'NNS'), 'amod', ('British', 'JJ')), (('History', 'NN'), 'appos', ('Volume', 'NN')), (('Volume', 'NN'), 'punct', ('(', '-LRB-')), (('Volume', 'NN'), 'nummod', ('1', 'CD')), (('Volume', 'NN'), 'punct', (',', ',')), (('Volume', 'NN'), 'nummod', ('1797', 'CD')), (('Volume', 'NN'), 'punct', (')', '-RRB-')), (('mentions', 'VBZ'), 'obj', ('report', 'NN')), (('report', 'NN'), 'det', ('a', 'DT')), (('report', 'NN'), 'nmod', ('master', 'NN')), (('master', 'NN'), 'case', ('from', 'IN')), (('master', 'NN'), 'punct', ('"', '``')), (('master', 'NN'), 'det', ('a', 'DT')), (('master', 'NN'), 'amod', ('intelligent', 'JJ')), (('intelligent', 'JJ'), 'advmod', ('very', 'RB')), (('master', 'NN'), 'nmod', ('vessel', 'NN')), (('vessel', 'NN'), 'case', ('of', 'IN')), (('vessel', 'NN'), 'det', ('a', 'DT')), (('master', 'NN'), 'punct', ('"', '``')), (('master', 'NN'), 'acl:relcl', ('saw', 'VBD')), (('saw', 'VBD'), 'obj', ('who', 'WP')), (('saw', 'VBD'), 'punct', (',', ',')), (('saw', 'VBD'), 'punct', ('"', '``')), (('saw', 'VBD'), 'obl', ('islands', 'NNS')), (('islands', 'NNS'), 'case', ('between', 'IN')), (('islands', 'NNS'), 'det', ('the', 'DT')), (('islands', 'NNS'), 'nmod', ('Minorca', 'NNP')), (('Minorca', 'NNP'), 'case', ('of', 'IN')), (('Minorca', 'NNP'), 'conj', ('Majorca', 'NNP')), (('Majorca', 'NNP'), 'cc', ('and', 'CC')), (('saw', 'VBD'), 'punct', (',', ',')), (('saw', 'VBD'), 'dep', ('flying', 'VBG')), (('flying', 'VBG'), 'nsubj', ('numbers', 'NNS')), (('numbers', 'NNS'), 'amod', ('great', 'JJ')), (('numbers', 'NNS'), 'nmod', ('Swallows', 'NNPS')), (('Swallows', 'NNPS'), 'case', ('of', 'IN')), (('flying', 'VBG'), 'advmod', ('northward', 'RB')), (('flying', 'VBG'), 'punct', ('"', "''")), (('saw', 'VBD'), 'punct', (',', ',')), (('saw', 'VBD'), 'conj', ('states', 'VBZ')), (('states', 'VBZ'), 'cc', ('and', 'CC')), (('states', 'VBZ'), 'obj', ('situation', 'NN')), (('situation', 'NN'), 'det', ('the', 'DT')), (('situation', 'NN'), 'nmod', ('Britain', 'NNP')), (('Britain', 'NNP'), 'case', ('in', 'IN')), (('states', 'VBZ'), 'dep', ('follows', 'VBZ')), (('follows', 'VBZ'), 'case', ('as', 'IN')), (('saw', 'VBD'), 'punct', (':', ':')), (('saw', 'VBD'), 'parataxis', ('describes', 'VBZ')), (('describes', 'VBZ'), 'nsubj', ('Bewick', 'NNP')), (('describes', 'VBZ'), 'advmod', ('then', 'RB')), (('describes', 'VBZ'), 'obj', ('experiment', 'NN')), (('experiment', 'NN'), 'det', ('an', 'DT')), (('experiment', 'NN'), 'acl:relcl', ('succeeded', 'VBD')), (('succeeded', 'VBD'), 'nsubj', ('which', 'WDT')), (('succeeded', 'VBD'), 'obl', ('swallows', 'NNS')), (('swallows', 'NNS'), 'case', ('in', 'IN')), (('swallows', 'NNS'), 'amod', ('keeping', 'VBG')), (('swallows', 'NNS'), 'amod', ('alive', 'JJ')), (('alive', 'JJ'), 'obl', ('Britain', 'NNP')), (('Britain', 'NNP'), 'case', ('in', 'IN')), (('succeeded', 'VBD'), 'obl', ('years', 'NNS')), (('years', 'NNS'), 'case', ('for', 'IN')), (('years', 'NNS'), 'amod', ('several', 'JJ')), (('years', 'NNS'), 'punct', (',', ',')), (('years', 'NNS'), 'acl:relcl', ('remained', 'VBD')), (('remained', 'VBD'), 'advmod', ('where', 'WRB')), (('remained', 'VBD'), 'nsubj', ('they', 'PRP')), (('remained', 'VBD'), 'xcomp', ('warm', 'JJ')), (('warm', 'JJ'), 'conj', ('dry', 'JJ')), (('dry', 'JJ'), 'cc', ('and', 'CC')), (('remained', 'VBD'), 'obl', ('winters', 'NNS')), (('winters', 'NNS'), 'case', ('through', 'IN')), (('winters', 'NNS'), 'det', ('the', 'DT')), (('mentions', 'VBZ'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['mentions']]
#
# ------SENTENCE------
# He concludes: Migration is the regular seasonal movement, often north and south, undertaken by many species of birds.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('concludes', 'VBZ'), 'nsubj', ('He', 'PRP')), (('concludes', 'VBZ'), 'punct', (':', ':')), (('concludes', 'VBZ'), 'parataxis', ('movement', 'NN')), (('movement', 'NN'), 'nsubj', ('Migration', 'NNP')), (('movement', 'NN'), 'cop', ('is', 'VBZ')), (('movement', 'NN'), 'det', ('the', 'DT')), (('movement', 'NN'), 'amod', ('regular', 'JJ')), (('movement', 'NN'), 'amod', ('seasonal', 'JJ')), (('movement', 'NN'), 'punct', (',', ',')), (('movement', 'NN'), 'advmod', ('north', 'RB')), (('north', 'RB'), 'advmod', ('often', 'RB')), (('north', 'RB'), 'conj', ('south', 'RB')), (('south', 'RB'), 'cc', ('and', 'CC')), (('movement', 'NN'), 'punct', (',', ',')), (('movement', 'NN'), 'acl', ('undertaken', 'VBN')), (('undertaken', 'VBN'), 'obl', ('species', 'NNS')), (('species', 'NNS'), 'case', ('by', 'IN')), (('species', 'NNS'), 'amod', ('many', 'JJ')), (('species', 'NNS'), 'nmod', ('birds', 'NNS')), (('birds', 'NNS'), 'case', ('of', 'IN')), (('concludes', 'VBZ'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['concludes']]
#
# ------SENTENCE------
# Bird movements include those made in response to changes in food availability, habitat, or weather.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('include', 'VBP'), 'nsubj', ('movements', 'NNS')), (('movements', 'NNS'), 'compound', ('Bird', 'NN')), (('include', 'VBP'), 'obj', ('those', 'DT')), (('those', 'DT'), 'acl', ('made', 'VBN')), (('made', 'VBN'), 'obl', ('response', 'NN')), (('response', 'NN'), 'case', ('in', 'IN')), (('response', 'NN'), 'nmod', ('changes', 'NNS')), (('changes', 'NNS'), 'case', ('to', 'IN')), (('changes', 'NNS'), 'nmod', ('availability', 'NN')), (('availability', 'NN'), 'case', ('in', 'IN')), (('availability', 'NN'), 'compound', ('food', 'NN')), (('availability', 'NN'), 'punct', (',', ',')), (('availability', 'NN'), 'conj', ('habitat', 'NN')), (('availability', 'NN'), 'punct', (',', ',')), (('availability', 'NN'), 'conj', ('weather', 'NN')), (('weather', 'NN'), 'cc', ('or', 'CC')), (('include', 'VBP'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['include']]
#
# ------SENTENCE------
# Sometimes, journeys are not termed "true migration" because they are irregular (nomadism, invasions, irruptions) or in only one direction (dispersal, movement of young away from natal area).
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('termed', 'VBN'), 'advmod', ('Sometimes', 'RB')), (('termed', 'VBN'), 'punct', (',', ',')), (('termed', 'VBN'), 'nsubj:pass', ('journeys', 'NNS')), (('termed', 'VBN'), 'aux:pass', ('are', 'VBP')), (('termed', 'VBN'), 'advmod', ('not', 'RB')), (('termed', 'VBN'), 'obj', ('migration', 'NN')), (('migration', 'NN'), 'punct', ('"', '``')), (('migration', 'NN'), 'amod', ('true', 'JJ')), (('migration', 'NN'), 'punct', ('"', "''")), (('termed', 'VBN'), 'advcl', ('irregular', 'JJ')), (('irregular', 'JJ'), 'mark', ('because', 'IN')), (('irregular', 'JJ'), 'nsubj', ('they', 'PRP')), (('irregular', 'JJ'), 'cop', ('are', 'VBP')), (('irregular', 'JJ'), 'dep', ('nomadism', 'NN')), (('nomadism', 'NN'), 'punct', ('(', '-LRB-')), (('nomadism', 'NN'), 'punct', (',', ',')), (('nomadism', 'NN'), 'conj', ('invasions', 'NNS')), (('nomadism', 'NN'), 'punct', (',', ',')), (('nomadism', 'NN'), 'conj', ('irruptions', 'NNS')), (('nomadism', 'NN'), 'punct', (')', '-RRB-')), (('irregular', 'JJ'), 'conj', ('direction', 'NN')), (('direction', 'NN'), 'cc', ('or', 'CC')), (('direction', 'NN'), 'case', ('in', 'IN')), (('direction', 'NN'), 'nummod', ('one', 'CD')), (('one', 'CD'), 'advmod', ('only', 'RB')), (('direction', 'NN'), 'dep', ('dispersal', 'NN')), (('dispersal', 'NN'), 'punct', ('(', '-LRB-')), (('dispersal', 'NN'), 'punct', (',', ',')), (('dispersal', 'NN'), 'appos', ('movement', 'NN')), (('movement', 'NN'), 'acl', ('of', 'IN')), (('of', 'IN'), 'dep', ('young', 'JJ')), (('young', 'JJ'), 'advmod', ('away', 'RB')), (('away', 'RB'), 'obl', ('area', 'NN')), (('area', 'NN'), 'case', ('from', 'IN')), (('area', 'NN'), 'amod', ('natal', 'JJ')), (('young', 'JJ'), 'punct', (')', '-RRB-')), (('termed', 'VBN'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['termed']]
#
# ------SENTENCE------
# Migration is marked by its annual seasonality.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('marked', 'VBN'), 'nsubj:pass', ('Migration', 'NNP')), (('marked', 'VBN'), 'aux:pass', ('is', 'VBZ')), (('marked', 'VBN'), 'obl', ('seasonality', 'NN')), (('seasonality', 'NN'), 'case', ('by', 'IN')), (('seasonality', 'NN'), 'nmod:poss', ('its', 'PRP$')), (('seasonality', 'NN'), 'amod', ('annual', 'JJ')), (('marked', 'VBN'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['marked']]
#
# ------SENTENCE------
# Non-migratory birds are said to be resident or sedentary.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('said', 'VBN'), 'nsubj:pass', ('birds', 'NNS')), (('birds', 'NNS'), 'amod', ('Non-migratory', 'JJ')), (('said', 'VBN'), 'aux:pass', ('are', 'VBP')), (('said', 'VBN'), 'xcomp', ('resident', 'JJ')), (('resident', 'JJ'), 'mark', ('to', 'TO')), (('resident', 'JJ'), 'cop', ('be', 'VB')), (('resident', 'JJ'), 'conj', ('sedentary', 'JJ')), (('sedentary', 'JJ'), 'cc', ('or', 'CC')), (('said', 'VBN'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['said']]
#
# ------SENTENCE------
# Approximately 1800 of the world's 10,000 bird species are long-distance migrants.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# ...
#
# ----Obtaining Heads----
# [['marked']]
#
# ------SENTENCE------
# Scientific ringing was pioneered by Hans Christian Cornelius Mortensen in 1899.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('pioneered', 'VBN'), 'nsubj:pass', ('Scientific', 'NNP')), (('Scientific', 'NNP'), 'acl', ('ringing', 'VBG')), (('pioneered', 'VBN'), 'aux:pass', ('was', 'VBD')), (('pioneered', 'VBN'), 'obl', ('Mortensen', 'NNP')), (('Mortensen', 'NNP'), 'case', ('by', 'IN')), (('Mortensen', 'NNP'), 'compound', ('Hans', 'NNP')), (('Mortensen', 'NNP'), 'compound', ('Christian', 'NNP')), (('Mortensen', 'NNP'), 'compound', ('Cornelius', 'NNP')), (('pioneered', 'VBN'), 'obl', ('1899', 'CD')), (('1899', 'CD'), 'case', ('in', 'IN')), (('pioneered', 'VBN'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['pioneered']]
#
# ------SENTENCE------
# Other techniques include radar and satellite tracking.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('include', 'VBP'), 'nsubj', ('techniques', 'NNS')), (('techniques', 'NNS'), 'amod', ('Other', 'JJ')), (('include', 'VBP'), 'obj', ('radar', 'NN')), (('radar', 'NN'), 'conj', ('tracking', 'NN')), (('tracking', 'NN'), 'cc', ('and', 'CC')), (('tracking', 'NN'), 'compound', ('satellite', 'NN')), (('include', 'VBP'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['include']]
#
# ------SENTENCE------
# Orientation behaviour studies have been traditionally carried out using variants of a setup known as the Emlen funnel, which consists of a circular cage with the top covered by glass or wire-screen so that either the sky is visible or the setup is placed in a planetarium or with other controls on environmental cues.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('carried', 'VBN'), 'nsubj:pass', ('studies', 'NNS')), (('studies', 'NNS'), 'compound', ('behaviour', 'NN')), (('behaviour', 'NN'), 'compound', ('Orientation', 'NN')), (('carried', 'VBN'), 'aux', ('have', 'VBP')), (('carried', 'VBN'), 'aux:pass', ('been', 'VBN')), (('carried', 'VBN'), 'advmod', ('traditionally', 'RB')), (('carried', 'VBN'), 'compound:prt', ('out', 'RP')), (('carried', 'VBN'), 'dep', ('using', 'VBG')), (('using', 'VBG'), 'obj', ('variants', 'NNS')), (('variants', 'NNS'), 'nmod', ('setup', 'NN')), (('setup', 'NN'), 'case', ('of', 'IN')), (('setup', 'NN'), 'det', ('a', 'DT')), (('setup', 'NN'), 'acl', ('known', 'VBN')), (('known', 'VBN'), 'obl', ('Emlen', 'NNP')), (('Emlen', 'NNP'), 'case', ('as', 'IN')), (('Emlen', 'NNP'), 'det', ('the', 'DT')), (('Emlen', 'NNP'), 'dep', ('funnel', 'VB')), (('Emlen', 'NNP'), 'punct', (',', ',')), (('Emlen', 'NNP'), 'acl:relcl', ('consists', 'VBZ')), (('consists', 'VBZ'), 'nsubj', ('which', 'WDT')), (('consists', 'VBZ'), 'obl', ('cage', 'NN')), (('cage', 'NN'), 'case', ('of', 'IN')), (('cage', 'NN'), 'det', ('a', 'DT')), (('cage', 'NN'), 'amod', ('circular', 'JJ')), (('cage', 'NN'), 'nmod', ('top', 'JJ')), (('top', 'JJ'), 'case', ('with', 'IN')), (('top', 'JJ'), 'det', ('the', 'DT')), (('cage', 'NN'), 'acl', ('covered', 'VBN')), (('covered', 'VBN'), 'dep', ('by', 'IN')), (('by', 'IN'), 'dep', ('glass', 'NN')), (('glass', 'NN'), 'conj', ('screen', 'NN')), (('screen', 'NN'), 'cc', ('or', 'CC')), (('screen', 'NN'), 'compound', ('wire', 'NN')), (('screen', 'NN'), 'punct', ('-', 'HYPH')), (('glass', 'NN'), 'dep', ('so', 'IN')), (('so', 'IN'), 'fixed', ('that', 'IN')), (('so', 'IN'), 'dep', ('visible', 'JJ')), (('visible', 'JJ'), 'cc:preconj', ('either', 'CC')), (('visible', 'JJ'), 'nsubj', ('sky', 'NN')), (('sky', 'NN'), 'det', ('the', 'DT')), (('visible', 'JJ'), 'cop', ('is', 'VBZ')), (('visible', 'JJ'), 'conj', ('placed', 'VBN')), (('placed', 'VBN'), 'cc', ('or', 'CC')), (('placed', 'VBN'), 'nsubj:pass', ('setup', 'NN')), (('setup', 'NN'), 'det', ('the', 'DT')), (('placed', 'VBN'), 'aux:pass', ('is', 'VBZ')), (('placed', 'VBN'), 'obl', ('planetarium', 'NN')), (('planetarium', 'NN'), 'case', ('in', 'IN')), (('planetarium', 'NN'), 'det', ('a', 'DT')), (('planetarium', 'NN'), 'conj', ('controls', 'NNS')), (('controls', 'NNS'), 'cc', ('or', 'CC')), (('controls', 'NNS'), 'case', ('with', 'IN')), (('controls', 'NNS'), 'amod', ('other', 'JJ')), (('controls', 'NNS'), 'nmod', ('cues', 'NNS')), (('cues', 'NNS'), 'case', ('on', 'IN')), (('cues', 'NNS'), 'amod', ('environmental', 'JJ')), (('carried', 'VBN'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['carried']]
#
# ------SENTENCE------
# The orientation behaviour of the bird inside the cage is studied quantitatively using the distribution of marks that the bird leaves on the walls of the cage.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('studied', 'VBN'), 'nsubj:pass', ('behaviour', 'NN')), (('behaviour', 'NN'), 'det', ('The', 'DT')), (('behaviour', 'NN'), 'compound', ('orientation', 'NN')), (('behaviour', 'NN'), 'nmod', ('bird', 'NN')), (('bird', 'NN'), 'case', ('of', 'IN')), (('bird', 'NN'), 'det', ('the', 'DT')), (('bird', 'NN'), 'nmod', ('cage', 'NN')), (('cage', 'NN'), 'case', ('inside', 'IN')), (('cage', 'NN'), 'det', ('the', 'DT')), (('studied', 'VBN'), 'aux:pass', ('is', 'VBZ')), (('studied', 'VBN'), 'dep', ('using', 'VBG')), (('using', 'VBG'), 'advmod', ('quantitatively', 'RB')), (('using', 'VBG'), 'obj', ('distribution', 'NN')), (('distribution', 'NN'), 'det', ('the', 'DT')), (('distribution', 'NN'), 'nmod', ('marks', 'NNS')), (('marks', 'NNS'), 'case', ('of', 'IN')), (('distribution', 'NN'), 'dep', ('leaves', 'VBZ')), (('leaves', 'VBZ'), 'mark', ('that', 'IN')), (('leaves', 'VBZ'), 'nsubj', ('bird', 'NN')), (('bird', 'NN'), 'det', ('the', 'DT')), (('leaves', 'VBZ'), 'obl', ('walls', 'NNS')), (('walls', 'NNS'), 'case', ('on', 'IN')), (('walls', 'NNS'), 'det', ('the', 'DT')), (('walls', 'NNS'), 'nmod', ('cage', 'NN')), (('cage', 'NN'), 'case', ('of', 'IN')), (('cage', 'NN'), 'det', ('the', 'DT')), (('studied', 'VBN'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['studied']]
#
# ------SENTENCE------
# Other approaches used in pigeon homing studies make use of the direction in which the bird vanishes on the horizon.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('used', 'VBN'), 'nsubj', ('approaches', 'NNS')), (('approaches', 'NNS'), 'amod', ('Other', 'JJ')), (('used', 'VBN'), 'obl', ('studies', 'NNS')), (('studies', 'NNS'), 'case', ('in', 'IN')), (('studies', 'NNS'), 'compound', ('homing', 'NN')), (('homing', 'NN'), 'compound', ('pigeon', 'NN')), (('used', 'VBN'), 'dep', ('make', 'VBP')), (('make', 'VBP'), 'obj', ('use', 'NN')), (('use', 'NN'), 'nmod', ('direction', 'NN')), (('direction', 'NN'), 'case', ('of', 'IN')), (('direction', 'NN'), 'det', ('the', 'DT')), (('direction', 'NN'), 'acl:relcl', ('vanishes', 'VBZ')), (('vanishes', 'VBZ'), 'obl', ('which', 'WDT')), (('which', 'WDT'), 'case', ('in', 'IN')), (('vanishes', 'VBZ'), 'nsubj', ('bird', 'NN')), (('bird', 'NN'), 'det', ('the', 'DT')), (('vanishes', 'VBZ'), 'obl', ('horizon', 'NN')), (('horizon', 'NN'), 'case', ('on', 'IN')), (('horizon', 'NN'), 'det', ('the', 'DT')), (('used', 'VBN'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['used']]
#
# ------SENTENCE------
# Hunting along migration routes threatens some bird species.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('threatens', 'VBZ'), 'nsubj', ('Hunting', 'NNP')), (('Hunting', 'NNP'), 'nmod', ('routes', 'NNS')), (('routes', 'NNS'), 'case', ('along', 'IN')), (('routes', 'NNS'), 'compound', ('migration', 'NN')), (('threatens', 'VBZ'), 'obj', ('species', 'NNS')), (('species', 'NNS'), 'det', ('some', 'DT')), (('species', 'NNS'), 'compound', ('bird', 'NN')), (('threatens', 'VBZ'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['threatens']]
#
# ------SENTENCE------
# The populations of Siberian cranes (Leucogeranus leucogeranus) that wintered in India declined due to hunting along the route, particularly in Afghanistan and Central Asia.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('populations', 'NNS'), 'det', ('The', 'DT')), (('populations', 'NNS'), 'nmod', ('cranes', 'NNS')), (('cranes', 'NNS'), 'case', ('of', 'IN')), (('cranes', 'NNS'), 'amod', ('Siberian', 'JJ')), (('cranes', 'NNS'), 'punct', ('(', '-LRB-')), (('cranes', 'NNS'), 'dep', ('leucogeranus', 'NNP')), (('leucogeranus', 'NNP'), 'compound', ('Leucogeranus', 'NNP')), (('cranes', 'NNS'), 'punct', (')', '-RRB-')), (('cranes', 'NNS'), 'acl:relcl', ('declined', 'VBD')), (('declined', 'VBD'), 'obj', ('that', 'WDT')), (('declined', 'VBD'), 'nsubj', ('wintered', 'VBD')), (('wintered', 'VBD'), 'obl', ('India', 'NNP')), (('India', 'NNP'), 'case', ('in', 'IN')), (('declined', 'VBD'), 'obl', ('hunting', 'VBG')), (('hunting', 'VBG'), 'case', ('due', 'IN')), (('due', 'IN'), 'fixed', ('to', 'IN')), (('hunting', 'VBG'), 'nmod', ('route', 'NN')), (('route', 'NN'), 'case', ('along', 'IN')), (('route', 'NN'), 'det', ('the', 'DT')), (('route', 'NN'), 'punct', (',', ',')), (('route', 'NN'), 'nmod', ('Afghanistan', 'NNP')), (('Afghanistan', 'NNP'), 'advmod', ('particularly', 'RB')), (('Afghanistan', 'NNP'), 'case', ('in', 'IN')), (('Afghanistan', 'NNP'), 'conj', ('Asia', 'NNP')), (('Asia', 'NNP'), 'cc', ('and', 'CC')), (('Asia', 'NNP'), 'compound', ('Central', 'NNP')), (('populations', 'NNS'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['populations']]
#
# ------SENTENCE------
# Birds were last seen in their favourite wintering grounds in Keoladeo National Park in 2002.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('seen', 'VBN'), 'nsubj:pass', ('Birds', 'NNS')), (('seen', 'VBN'), 'aux:pass', ('were', 'VBD')), (('seen', 'VBN'), 'advmod', ('last', 'JJ')), (('seen', 'VBN'), 'obl', ('favourite', 'NN')), (('favourite', 'NN'), 'case', ('in', 'IN')), (('favourite', 'NN'), 'nmod:poss', ('their', 'PRP$')), (('favourite', 'NN'), 'dep', ('grounds', 'NNS')), (('grounds', 'NNS'), 'amod', ('wintering', 'VBG')), (('grounds', 'NNS'), 'nmod', ('Park', 'NNP')), (('Park', 'NNP'), 'case', ('in', 'IN')), (('Park', 'NNP'), 'compound', ('Keoladeo', 'NNP')), (('Park', 'NNP'), 'compound', ('National', 'NNP')), (('seen', 'VBN'), 'obl', ('2002', 'CD')), (('2002', 'CD'), 'case', ('in', 'IN')), (('seen', 'VBN'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['seen']]
#
# ------SENTENCE------
# Structures such as power lines, wind farms and offshore oil-rigs have also been known to affect migratory birds.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('known', 'VBN'), 'nsubj:pass', ('Structures', 'NNS')), (('Structures', 'NNS'), 'nmod', ('lines', 'NNS')), (('lines', 'NNS'), 'case', ('such', 'JJ')), (('such', 'JJ'), 'fixed', ('as', 'IN')), (('lines', 'NNS'), 'compound', ('power', 'NN')), (('lines', 'NNS'), 'punct', (',', ',')), (('lines', 'NNS'), 'conj', ('farms', 'NNS')), (('farms', 'NNS'), 'compound', ('wind', 'NN')), (('lines', 'NNS'), 'conj', ('rigs', 'NNS')), (('rigs', 'NNS'), 'cc', ('and', 'CC')), (('rigs', 'NNS'), 'amod', ('offshore', 'JJ')), (('rigs', 'NNS'), 'compound', ('oil', 'NN')), (('rigs', 'NNS'), 'punct', ('-', 'HYPH')), (('known', 'VBN'), 'aux', ('have', 'VBP')), (('known', 'VBN'), 'advmod', ('also', 'RB')), (('known', 'VBN'), 'aux:pass', ('been', 'VBN')), (('known', 'VBN'), 'xcomp', ('affect', 'VB')), (('affect', 'VB'), 'mark', ('to', 'TO')), (('affect', 'VB'), 'obj', ('birds', 'NNS')), (('birds', 'NNS'), 'amod', ('migratory', 'JJ')), (('known', 'VBN'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['known']]
#
# ------SENTENCE------
# Other migration hazards include pollution, storms, wildfires, and habitat destruction along migration routes, denying migrants food at stopover points.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('include', 'VBP'), 'nsubj', ('hazards', 'NNS')), (('hazards', 'NNS'), 'amod', ('Other', 'JJ')), (('hazards', 'NNS'), 'compound', ('migration', 'NN')), (('include', 'VBP'), 'obj', ('pollution', 'NN')), (('pollution', 'NN'), 'punct', (',', ',')), (('pollution', 'NN'), 'conj', ('storms', 'NNS')), (('pollution', 'NN'), 'punct', (',', ',')), (('pollution', 'NN'), 'conj', ('wildfires', 'NNS')), (('pollution', 'NN'), 'punct', (',', ',')), (('pollution', 'NN'), 'conj', ('destruction', 'NN')), (('destruction', 'NN'), 'cc', ('and', 'CC')), (('destruction', 'NN'), 'compound', ('habitat', 'NN')), (('destruction', 'NN'), 'nmod', ('routes', 'NNS')), (('routes', 'NNS'), 'case', ('along', 'IN')), (('routes', 'NNS'), 'compound', ('migration', 'NN')), (('pollution', 'NN'), 'punct', (',', ',')), (('pollution', 'NN'), 'acl', ('denying', 'VBG')), (('denying', 'VBG'), 'obj', ('food', 'NN')), (('food', 'NN'), 'compound', ('migrants', 'NNS')), (('denying', 'VBG'), 'obl', ('points', 'NNS')), (('points', 'NNS'), 'case', ('at', 'IN')), (('points', 'NNS'), 'compound', ('stopover', 'NN')), (('include', 'VBP'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['include']]
#
# ------SENTENCE------
# For example, in the East Asian–Australasian Flyway, up to 65% of key intertidal habitat at the Yellow Sea migration bottleneck has been destroyed since the 1950s.
#
# ----Word Tokenization----
#
# ----Word Lemmatization----
#
# ----POS Tagging----
#
# ----WordNet Feature Extraction----
#
# ----Dependency Parsing----
# [(('destroyed', 'VBN'), 'obl', ('example', 'NN')), (('example', 'NN'), 'case', ('For', 'IN')), (('destroyed', 'VBN'), 'punct', (',', ',')), (('destroyed', 'VBN'), 'obl', ('Asian', 'NNP')), (('Asian', 'NNP'), 'case', ('in', 'IN')), (('Asian', 'NNP'), 'det', ('the', 'DT')), (('Asian', 'NNP'), 'compound', ('East', 'NNP')), (('Asian', 'NNP'), 'dep', ('–', 'SYM')), (('destroyed', 'VBN'), 'nsubj:pass', ('Flyway', 'NNP')), (('Flyway', 'NNP'), 'compound', ('Australasian', 'NNP')), (('Flyway', 'NNP'), 'punct', (',', ',')), (('Flyway', 'NNP'), 'appos', ('%', 'NN')), (('%', 'NN'), 'nummod', ('65', 'CD')), (('65', 'CD'), 'advmod', ('up', 'RB')), (('65', 'CD'), 'advmod', ('to', 'IN')), (('%', 'NN'), 'nmod', ('habitat', 'NN')), (('habitat', 'NN'), 'case', ('of', 'IN')), (('habitat', 'NN'), 'amod', ('key', 'JJ')), (('habitat', 'NN'), 'amod', ('intertidal', 'JJ')), (('habitat', 'NN'), 'nmod', ('bottleneck', 'NN')), (('bottleneck', 'NN'), 'case', ('at', 'IN')), (('bottleneck', 'NN'), 'det', ('the', 'DT')), (('bottleneck', 'NN'), 'compound', ('Sea', 'NNP')), (('Sea', 'NNP'), 'compound', ('Yellow', 'NNP')), (('bottleneck', 'NN'), 'compound', ('migration', 'NN')), (('destroyed', 'VBN'), 'aux', ('has', 'VBZ')), (('destroyed', 'VBN'), 'aux:pass', ('been', 'VBN')), (('destroyed', 'VBN'), 'obl', ('1950s', 'NNS')), (('1950s', 'NNS'), 'case', ('since', 'IN')), (('1950s', 'NNS'), 'det', ('the', 'DT')), (('destroyed', 'VBN'), 'punct', ('.', '.'))]
#
# ----Obtaining Heads----
# [['destroyed']]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-9e6833edcc17> in <module>
#     295
#     296     output_name = 'pipeline/parsed-' + articleNames[i]
# --> 297     with open(output_name, 'w', encoding='utf8') as output_file:
#     298         json.dump(corpus_dict, output_file,  indent=4, sort_keys=True,
#     299                   separators=(',', ': '), ensure_ascii=False)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pipeline/parsed-109.txt'
