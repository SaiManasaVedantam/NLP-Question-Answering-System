# %%
#This file implements all the mandatory feature extraction specified in Task 1.
#    It only prints the features. We save these features along with few more in the actual training file.
#   Features extracted here are:
#    1. Text tokenization into sentences & words
#    2. Word Lemmatization
#    3. Part-of-Speech (POS) tagging
#    4. Dependency Parsing
#    5. WordNet features - Hypernymns, Hyponyms, Meronyms, Holonyms

# %%
# Turn off unnecessary warnings
import warnings
warnings.filterwarnings("ignore")

# Import all the required packages
import json
import nltk
import string
import urllib
from pprint import pprint
from nltk.corpus import wordnet as wn
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize, sent_tokenize 
from nltk.wsd import lesk
from nltk.parse import CoreNLPParser
from nltk.corpus import stopwords
from nltk.parse.corenlp import CoreNLPDependencyParser

# %%
# Start common things globally
stop_words = stopwords.words('english') + list(string.punctuation)
dependencyParser = CoreNLPDependencyParser(url='http://localhost:9000')
wordnet_lemmatizer = WordNetLemmatizer()
tokenizer = nltk.data.load("tokenizers/punkt/english.pickle")

# %%
# Performs Word tokenization on sentences
def Tokenization(sentence):
    tokens = [i for i in nltk.word_tokenize(sentence.lower()) if i not in stop_words]
    return tokens


# Performs Word Lemmatization : Uses context
def Lemmatization(word_tokens):
    lemmas = []
    for token in word_tokens:
        lemmas.append(wordnet_lemmatizer.lemmatize(token))
    return lemmas


# Performs POS tagging
def POSTagging(sentence):
    word_tokens = [i for i in nltk.word_tokenize(sentence.lower()) if i not in stop_words]
    POStags = nltk.pos_tag(word_tokens)
    return POStags

# %%
# Performs Dependency Parsing
def DependencyParsing(sentence):
    # Perform dependency parsing
    parse, = dependencyParser.raw_parse(sentence)
    
    # Dependency parsing to parse tree based patterns as features
    depParseResult = list(parse.triples())
    
    return depParseResult

# %%
# Obtains WordNet Features
def WordNetFeatures(sentence, word_tokens):
    # Creates dictionaries for important word senses
    hypernyms_list = []
    hyponyms_list = []
    meronyms_list = []
    holonyms_list = []
    synonyms_list = []
    
    # Populates the above dictionaries according to the word senses associated with them
    for token in word_tokens:
        # Extracts best sense for each word using LESK
        best_sense = lesk(sentence, token)
        
        if best_sense is not None:
            # Obtains Synonyms
            synonym = token
            if best_sense. lemmas()[0].name() != token:
                synonym = best_sense.lemmas()[0].name()
            synonyms_list.append(synonym)
            
            # Obtains Hypernyms
            if best_sense.hypernyms() != []:
                hypernyms_list.append(best_sense.hypernyms()[0].lemmas()[0].name())
        
            # Obtains Hyponyms
            if best_sense.hyponyms() != []:
                hyponyms_list.append(best_sense.hyponyms()[0].lemmas()[0].name())
            
            # Obtains Meronyms
            if best_sense.part_meronyms() != []:
                meronyms_list.append(best_sense.part_meronyms()[0].lemmas()[0].name())
                
            # Obtains Holonyms
            if best_sense.part_holonyms() != []:
                holonyms_list.append(best_sense.part_holonyms()[0].lemmas()[0].name())
          
        # When there's no best sense, the token itself is the Synonym
        else:
            synonyms_list.append(token)
            
    return hypernyms_list, hyponyms_list, meronyms_list, holonyms_list, synonyms_list

# %%
# NLP pipeline through which all the articles & question will pass
def NLP_Pipeline(sentence):
    print("\n------SENTENCE------")
    print(sen)

    word_tokens = Tokenization(sentence)
    print("\nWord Tokenization : Done")
    print(word_tokens)
    
    word_POStags = POSTagging(sentence)
    print("\nPOS Tagging : Done")
    print(word_POStags)
    
    word_lemmas = Lemmatization(word_tokens)
    print("\nWord Lemmatization : Done")
    print(word_lemmas)

    hypernyms, hyponyms, meronyms, holonyms, synonyms = WordNetFeatures(sentence, word_tokens)
    print("\nWordNet Feature Extraction : Done")
    
    print("\nSynonyms")
    print(synonyms)
    
    print("\nHolonyms")
    print(holonyms)
    
    print("\nMeronyms")
    print(meronyms)
    
    print("\nHyponyms")
    print(hyponyms)
    
    print("\nHypernyms")
    print(hypernyms)
            
    depParse = DependencyParsing(sentence)
    print("\nDependency Parsing : Done")
    pprint(depParse)

# %%
# Get contents from the sample file
urlPath = "https://raw.githubusercontent.com/SaiManasaVedantam/NLP-QA-System-Datasets/main/"
fileName = urlPath + "Sample-6.txt"
response = urllib.request.urlopen(fileName)
webContents = response.read()
stringTypeData = webContents.decode("utf-8")
content = stringTypeData

print("Started processing the sample file")

# Get tokenized sentences
sentences = []
sentences.extend(tokenizer.tokenize(content))

# Sentence count
#print("Total Sentences After splitting the document: ", len(sentences))
print("Extracting features for each sentence in the file...")
    
# Extracting words
for sen in sentences:
    NLP_Pipeline(sen)
        
print("Completed processing the sample file")    
print("\nSample Task 1 Successfully Completed !!!")
# Out:
# Started processing the sample file
# Extracting features for each sentence in the file...
#
# ------SENTENCE------
# The exact nature of relations between Tibet and the Ming dynasty of China (1368–1644) is unclear.
#
# Word Tokenization : Done
# ['exact', 'nature', 'relations', 'tibet', 'ming', 'dynasty', 'china', '1368–1644', 'unclear']
#
# POS Tagging : Done
# [('exact', 'JJ'), ('nature', 'NN'), ('relations', 'NNS'), ('tibet', 'VBP'), ('ming', 'VBG'), ('dynasty', 'JJ'), ('china', 'NN'), ('1368–1644', 'CD'), ('unclear', 'JJ')]
#
# Word Lemmatization : Done
# ['exact', 'nature', 'relation', 'tibet', 'ming', 'dynasty', 'china', '1368–1644', 'unclear']
#
# WordNet Feature Extraction : Done
#
# Synonyms
# ['exact', 'nature', 'sexual_intercourse', 'Tibet', 'Ming', 'dynasty', 'Taiwan', '1368–1644', 'unclear']
#
# Holonyms
# ['Asia', 'South_China_Sea']
#
# Meronyms
# ['insemination', 'Changtzu', 'Taichung']
#
# Hyponyms
# ['defloration', 'Bourbon']
#
# Hypernyms
# ['type', 'sexual_activity', 'dynasty', 'family']
#
# Dependency Parsing : Done
# [(('unclear', 'JJ'), 'nsubj', ('nature', 'NN')),
#  (('nature', 'NN'), 'det', ('The', 'DT')),
#  (('nature', 'NN'), 'amod', ('exact', 'JJ')),
#  (('nature', 'NN'), 'nmod', ('relations', 'NNS')),
#  (('relations', 'NNS'), 'case', ('of', 'IN')),
#  (('relations', 'NNS'), 'nmod', ('Tibet', 'NNP')),
#  (('Tibet', 'NNP'), 'case', ('between', 'IN')),
#  (('Tibet', 'NNP'), 'conj', ('dynasty', 'NN')),
#  (('dynasty', 'NN'), 'cc', ('and', 'CC')),
#  (('dynasty', 'NN'), 'det', ('the', 'DT')),
#  (('dynasty', 'NN'), 'compound', ('Ming', 'NNP')),
#  (('dynasty', 'NN'), 'nmod', ('China', 'NNP')),
#  (('China', 'NNP'), 'case', ('of', 'IN')),
#  (('nature', 'NN'), 'dep', ('1368', 'CD')),
#  (('1368', 'CD'), 'punct', ('(', '-LRB-')),
#  (('1368', 'CD'), 'nmod', ('1644', 'CD')),
#  (('1644', 'CD'), 'dep', ('–', 'SYM')),
#  (('1368', 'CD'), 'punct', (')', '-RRB-')),
#  (('unclear', 'JJ'), 'cop', ('is', 'VBZ')),
#  (('unclear', 'JJ'), 'punct', ('.', '.'))]
#
# ------SENTENCE------
# Analysis of the relationship is further complicated by modern political conflicts and the application of Westphalian sovereignty to a time when the concept did not exist.
#
# Word Tokenization : Done
# ['analysis', 'relationship', 'complicated', 'modern', 'political', 'conflicts', 'application', 'westphalian', 'sovereignty', 'time', 'concept', 'exist']
#
# POS Tagging : Done
# [('analysis', 'NN'), ('relationship', 'NN'), ('complicated', 'VBD'), ('modern', 'JJ'), ('political', 'JJ'), ('conflicts', 'NNS'), ('application', 'NN'), ('westphalian', 'JJ'), ('sovereignty', 'NN'), ('time', 'NN'), ('concept', 'NN'), ('exist', 'VBP')]
#
# Word Lemmatization : Done
# ['analysis', 'relationship', 'complicated', 'modern', 'political', 'conflict', 'application', 'westphalian', 'sovereignty', 'time', 'concept', 'exist']
#
# WordNet Feature Extraction : Done
#
# Synonyms
# ['psychoanalysis', 'relationship', 'complicated', 'Modern', 'political', 'dispute', 'lotion', 'westphalian', 'sovereignty', 'time', 'concept', 'exist']
#
# Holonyms
# []
#
# Meronyms
# []
#
# Hyponyms
# ['hypnoanalysis', 'account', 'collision', 'blackwash', 'abstraction', 'breathe']
#
# Hypernyms
# ['psychotherapy', 'state', 'disagreement', 'remedy', 'authority', 'adjust', 'idea']
#
# Dependency Parsing : Done
# [(('complicated', 'VBN'), 'nsubj:pass', ('Analysis', 'NN')),
#  (('Analysis', 'NN'), 'nmod', ('relationship', 'NN')),
#  (('relationship', 'NN'), 'case', ('of', 'IN')),
#  (('relationship', 'NN'), 'det', ('the', 'DT')),
#  (('complicated', 'VBN'), 'aux:pass', ('is', 'VBZ')),
#  (('complicated', 'VBN'), 'advmod', ('further', 'RBR')),
#  (('complicated', 'VBN'), 'obl', ('conflicts', 'NNS')),
#  (('conflicts', 'NNS'), 'case', ('by', 'IN')),
#  (('conflicts', 'NNS'), 'amod', ('modern', 'JJ')),
#  (('conflicts', 'NNS'), 'amod', ('political', 'JJ')),
#  (('conflicts', 'NNS'), 'conj', ('application', 'NN')),
#  (('application', 'NN'), 'cc', ('and', 'CC')),
#  (('application', 'NN'), 'det', ('the', 'DT')),
#  (('application', 'NN'), 'nmod', ('sovereignty', 'NN')),
#  (('sovereignty', 'NN'), 'case', ('of', 'IN')),
#  (('sovereignty', 'NN'), 'amod', ('Westphalian', 'JJ')),
#  (('application', 'NN'), 'nmod', ('time', 'NN')),
#  (('time', 'NN'), 'case', ('to', 'IN')),
#  (('time', 'NN'), 'det', ('a', 'DT')),
#  (('time', 'NN'), 'acl:relcl', ('exist', 'VB')),
#  (('exist', 'VB'), 'advmod', ('when', 'WRB')),
#  (('exist', 'VB'), 'nsubj', ('concept', 'NN')),
#  (('concept', 'NN'), 'det', ('the', 'DT')),
#  (('exist', 'VB'), 'aux', ('did', 'VBD')),
#  (('exist', 'VB'), 'advmod', ('not', 'RB')),
#  (('complicated', 'VBN'), 'punct', ('.', '.'))]
#
# ------SENTENCE------
# Some Mainland Chinese scholars, such as Wang Jiawei and Nyima Gyaincain, assert that the Ming dynasty had unquestioned sovereignty over Tibet, pointing to the Ming court's issuing of various titles to Tibetan leaders, Tibetans' full acceptance of these titles, and a renewal process for successors of these titles that involved traveling to the Ming capital.
#
# Word Tokenization : Done
# ['mainland', 'chinese', 'scholars', 'wang', 'jiawei', 'nyima', 'gyaincain', 'assert', 'ming', 'dynasty', 'unquestioned', 'sovereignty', 'tibet', 'pointing', 'ming', 'court', "'s", 'issuing', 'various', 'titles', 'tibetan', 'leaders', 'tibetans', 'full', 'acceptance', 'titles', 'renewal', 'process', 'successors', 'titles', 'involved', 'traveling', 'ming', 'capital']
#
# POS Tagging : Done
# [('mainland', 'NN'), ('chinese', 'JJ'), ('scholars', 'NNS'), ('wang', 'VBP'), ('jiawei', 'JJ'), ('nyima', 'RB'), ('gyaincain', 'VBP'), ('assert', 'JJ'), ('ming', 'VBG'), ('dynasty', 'NN'), ('unquestioned', 'VBD'), ('sovereignty', 'JJ'), ('tibet', 'NN'), ('pointing', 'VBG'), ('ming', 'VBG'), ('court', 'NN'), ("'s", 'POS'), ('issuing', 'VBG'), ('various', 'JJ'), ('titles', 'NNS'), ('tibetan', 'VBP'), ('leaders', 'NNS'), ('tibetans', 'NNS'), ('full', 'JJ'), ('acceptance', 'NN'), ('titles', 'NNS'), ('renewal', 'VBP'), ('process', 'NN'), ('successors', 'NNS'), ('titles', 'NNS'), ('involved', 'VBD'), ('traveling', 'VBG'), ('ming', 'VBG'), ('capital', 'NN')]
#
# Word Lemmatization : Done
# ['mainland', 'chinese', 'scholar', 'wang', 'jiawei', 'nyima', 'gyaincain', 'assert', 'ming', 'dynasty', 'unquestioned', 'sovereignty', 'tibet', 'pointing', 'ming', 'court', "'s", 'issuing', 'various', 'title', 'tibetan', 'leader', 'tibetan', 'full', 'acceptance', 'title', 'renewal', 'process', 'successor', 'title', 'involved', 'traveling', 'ming', 'capital']
#
# WordNet Feature Extraction : Done
#
# Synonyms
# ['mainland', 'Chinese', 'scholar', 'wang', 'jiawei', 'nyima', 'gyaincain', 'insist', 'Ming', 'dynasty', 'undisputed', 'sovereignty', 'Tibet', 'target', 'Ming', 'motor_hotel', "'s", 'issue', 'versatile', 'title', 'Tibetan', 'leadership', 'Tibetan', 'fully', 'toleration', 'title', 'renewal', 'work', 'successor', 'title', 'involve', 'travel', 'Ming', 'Das_Kapital']
#
# Holonyms
# ['Asia']
#
# Meronyms
# ['Changtzu']
#
# Hyponyms
# ['Boxer', 'Rhodes_scholar', 'Bourbon', 'address', 'motel', 'high_command', 'self_acceptance', 'self-renewal', 'coldwork', 'itinerate']
#
# Hypernyms
# ['land', 'Asian', 'student', 'postulate', 'dynasty', 'family', 'authority', 'aim', 'dynasty', 'hotel', 'communicate', 'writing', 'Asian', 'body', 'Asian', 'permissiveness', 'writing', 'repetition', 'transform', 'offspring', 'writing', 'include', 'travel', 'dynasty']
#
# Dependency Parsing : Done
# [(('assert', 'VBP'), 'nsubj', ('scholars', 'NNS')),
#  (('scholars', 'NNS'), 'det', ('Some', 'DT')),
#  (('scholars', 'NNS'), 'compound', ('Mainland', 'NN')),
#  (('scholars', 'NNS'), 'amod', ('Chinese', 'JJ')),
#  (('scholars', 'NNS'), 'punct', (',', ',')),
#  (('scholars', 'NNS'), 'nmod', ('Jiawei', 'NNP')),
#  (('Jiawei', 'NNP'), 'case', ('such', 'JJ')),
#  (('such', 'JJ'), 'fixed', ('as', 'IN')),
#  (('Jiawei', 'NNP'), 'compound', ('Wang', 'NNP')),
#  (('Jiawei', 'NNP'), 'conj', ('Gyaincain', 'NNP')),
#  (('Gyaincain', 'NNP'), 'cc', ('and', 'CC')),
#  (('Gyaincain', 'NNP'), 'compound', ('Nyima', 'NNP')),
#  (('assert', 'VBP'), 'punct', (',', ',')),
#  (('assert', 'VBP'), 'ccomp', ('had', 'VBD')),
#  (('had', 'VBD'), 'mark', ('that', 'IN')),
#  (('had', 'VBD'), 'nsubj', ('dynasty', 'NN')),
#  (('dynasty', 'NN'), 'det', ('the', 'DT')),
#  (('dynasty', 'NN'), 'compound', ('Ming', 'NNP')),
#  (('had', 'VBD'), 'obj', ('sovereignty', 'NN')),
#  (('sovereignty', 'NN'), 'amod', ('unquestioned', 'JJ')),
#  (('sovereignty', 'NN'), 'nmod', ('Tibet', 'NNP')),
#  (('Tibet', 'NNP'), 'case', ('over', 'IN')),
#  (('had', 'VBD'), 'punct', (',', ',')),
#  (('had', 'VBD'), 'conj', ('pointing', 'VBG')),
#  (('pointing', 'VBG'), 'obl', ('issuing', 'NN')),
#  (('issuing', 'NN'), 'case', ('to', 'IN')),
#  (('issuing', 'NN'), 'nmod:poss', ('court', 'NN')),
#  (('court', 'NN'), 'det', ('the', 'DT')),
#  (('court', 'NN'), 'compound', ('Ming', 'NNP')),
#  (('court', 'NN'), 'case', ("'s", 'POS')),
#  (('issuing', 'NN'), 'nmod', ('titles', 'NNS')),
#  (('titles', 'NNS'), 'case', ('of', 'IN')),
#  (('titles', 'NNS'), 'amod', ('various', 'JJ')),
#  (('issuing', 'NN'), 'nmod', ('leaders', 'NNS')),
#  (('leaders', 'NNS'), 'case', ('to', 'IN')),
#  (('leaders', 'NNS'), 'amod', ('Tibetan', 'JJ')),
#  (('had', 'VBD'), 'punct', (',', ',')),
#  (('had', 'VBD'), 'conj', ('acceptance', 'NN')),
#  (('acceptance', 'NN'), 'nmod:poss', ('Tibetans', 'NNPS')),
#  (('Tibetans', 'NNPS'), 'case', ("'", 'POS')),
#  (('acceptance', 'NN'), 'amod', ('full', 'JJ')),
#  (('acceptance', 'NN'), 'nmod', ('titles', 'NNS')),
#  (('titles', 'NNS'), 'case', ('of', 'IN')),
#  (('titles', 'NNS'), 'det', ('these', 'DT')),
#  (('had', 'VBD'), 'punct', (',', ',')),
#  (('had', 'VBD'), 'conj', ('process', 'NN')),
#  (('process', 'NN'), 'cc', ('and', 'CC')),
#  (('process', 'NN'), 'det', ('a', 'DT')),
#  (('process', 'NN'), 'compound', ('renewal', 'NN')),
#  (('process', 'NN'), 'nmod', ('successors', 'NNS')),
#  (('successors', 'NNS'), 'case', ('for', 'IN')),
#  (('successors', 'NNS'), 'nmod', ('titles', 'NNS')),
#  (('titles', 'NNS'), 'case', ('of', 'IN')),
#  (('titles', 'NNS'), 'det', ('these', 'DT')),
#  (('process', 'NN'), 'dep', ('that', 'WDT')),
#  (('that', 'WDT'), 'dep', ('involved', 'VBD')),
#  (('involved', 'VBD'), 'acl', ('traveling', 'VBG')),
#  (('traveling', 'VBG'), 'obl', ('capital', 'NN')),
#  (('capital', 'NN'), 'case', ('to', 'IN')),
#  (('capital', 'NN'), 'det', ('the', 'DT')),
#  (('capital', 'NN'), 'compound', ('Ming', 'NNP')),
#  (('assert', 'VBP'), 'punct', ('.', '.'))]
#
# ------SENTENCE------
# Scholars within China also argue that Tibet has been an integral part of China since the 13th century and that it was thus a part of the Ming Empire.
#
# Word Tokenization : Done
# ['scholars', 'within', 'china', 'also', 'argue', 'tibet', 'integral', 'part', 'china', 'since', '13th', 'century', 'thus', 'part', 'ming', 'empire']
#
# POS Tagging : Done
# [('scholars', 'NNS'), ('within', 'IN'), ('china', 'NN'), ('also', 'RB'), ('argue', 'JJ'), ('tibet', 'IN'), ('integral', 'JJ'), ('part', 'NN'), ('china', 'NN'), ('since', 'IN'), ('13th', 'JJ'), ('century', 'NN'), ('thus', 'RB'), ('part', 'NN'), ('ming', 'NN'), ('empire', 'NN')]
#
# Word Lemmatization : Done
# ['scholar', 'within', 'china', 'also', 'argue', 'tibet', 'integral', 'part', 'china', 'since', '13th', 'century', 'thus', 'part', 'ming', 'empire']
#
# WordNet Feature Extraction : Done
#
# Synonyms
# ['scholar', 'inside', 'Taiwan', 'besides', 'argue', 'Tibet', 'integral', 'part', 'Taiwan', 'since', 'thirteenth', 'century', 'thus', 'part', 'Ming', 'Empire']
#
# Holonyms
# ['South_China_Sea', 'Asia', 'South_China_Sea', 'millennium']
#
# Meronyms
# ['Taichung', 'Changtzu', 'Taichung', 'decade']
#
# Hyponyms
# ['Rhodes_scholar', 'definite_integral', 'accompaniment', 'quattrocento', 'accompaniment']
#
# Hypernyms
# ['student', 'present', 'calculation', 'tune', 'time_period', 'tune', 'dynasty', 'eating_apple']
#
# Dependency Parsing : Done
# [(('argue', 'VBP'), 'nsubj', ('Scholars', 'NNS')),
#  (('Scholars', 'NNS'), 'nmod', ('China', 'NNP')),
#  (('China', 'NNP'), 'case', ('within', 'IN')),
#  (('argue', 'VBP'), 'advmod', ('also', 'RB')),
#  (('argue', 'VBP'), 'ccomp', ('part', 'NN')),
#  (('part', 'NN'), 'mark', ('that', 'IN')),
#  (('part', 'NN'), 'nsubj', ('Tibet', 'NNP')),
#  (('part', 'NN'), 'aux', ('has', 'VBZ')),
#  (('part', 'NN'), 'cop', ('been', 'VBN')),
#  (('part', 'NN'), 'det', ('an', 'DT')),
#  (('part', 'NN'), 'amod', ('integral', 'JJ')),
#  (('part', 'NN'), 'nmod', ('China', 'NNP')),
#  (('China', 'NNP'), 'case', ('of', 'IN')),
#  (('part', 'NN'), 'nmod', ('century', 'NN')),
#  (('century', 'NN'), 'case', ('since', 'IN')),
#  (('century', 'NN'), 'det', ('the', 'DT')),
#  (('century', 'NN'), 'amod', ('13th', 'JJ')),
#  (('part', 'NN'), 'conj', ('part', 'NN')),
#  (('part', 'NN'), 'cc', ('and', 'CC')),
#  (('part', 'NN'), 'mark', ('that', 'IN')),
#  (('part', 'NN'), 'nsubj', ('it', 'PRP')),
#  (('part', 'NN'), 'cop', ('was', 'VBD')),
#  (('part', 'NN'), 'advmod', ('thus', 'RB')),
#  (('part', 'NN'), 'det', ('a', 'DT')),
#  (('part', 'NN'), 'nmod', ('Empire', 'NNP')),
#  (('Empire', 'NNP'), 'case', ('of', 'IN')),
#  (('Empire', 'NNP'), 'det', ('the', 'DT')),
#  (('Empire', 'NNP'), 'compound', ('Ming', 'NNP')),
#  (('argue', 'VBP'), 'punct', ('.', '.'))]
#
# ------SENTENCE------
# But most scholars outside China, such as Turrell V. Wylie, Melvin C. Goldstein, and Helmut Hoffman, say that the relationship was one of suzerainty, that Ming titles were only nominal, that Tibet remained an independent region outside Ming control, and that it simply paid tribute until the Jiajing Emperor (1521–1566), who ceased relations with Tibet.
#
# Word Tokenization : Done
# ['scholars', 'outside', 'china', 'turrell', 'v.', 'wylie', 'melvin', 'c.', 'goldstein', 'helmut', 'hoffman', 'say', 'relationship', 'one', 'suzerainty', 'ming', 'titles', 'nominal', 'tibet', 'remained', 'independent', 'region', 'outside', 'ming', 'control', 'simply', 'paid', 'tribute', 'jiajing', 'emperor', '1521–1566', 'ceased', 'relations', 'tibet']
# POS Tagging : Done
# [('scholars', 'NNS'), ('outside', 'IN'), ('china', 'NN'), ('turrell', 'NN'), ('v.', 'FW'), ('wylie', 'WP'), ('melvin', 'FW'), ('c.', 'NN'), ('goldstein', 'NN'), ('helmut', 'JJ'), ('hoffman', 'NNS'), ('say', 'VBP'), ('relationship', 'NN'), ('one', 'CD'), ('suzerainty', 'NN'), ('ming', 'NN'), ('titles', 'NNS'), ('nominal', 'JJ'), ('tibet', 'NN'), ('remained', 'VBD'), ('independent', 'JJ'), ('region', 'NN'), ('outside', 'IN'), ('ming', 'VBG'), ('control', 'NN'), ('simply', 'RB'), ('paid', 'VBD'), ('tribute', 'NN'), ('jiajing', 'NN'), ('emperor', 'NN'), ('1521–1566', 'CD'), ('ceased', 'JJ'), ('relations', 'NNS'), ('tibet', 'NN')]
#
# Word Lemmatization : Done
# ['scholar', 'outside', 'china', 'turrell', 'v.', 'wylie', 'melvin', 'c.', 'goldstein', 'helmut', 'hoffman', 'say', 'relationship', 'one', 'suzerainty', 'ming', 'title', 'nominal', 'tibet', 'remained', 'independent', 'region', 'outside', 'ming', 'control', 'simply', 'paid', 'tribute', 'jiajing', 'emperor', '1521–1566', 'ceased', 'relation', 'tibet']
#
# WordNet Feature Extraction : Done
#
# Synonyms
# ['scholar', 'outside', 'Taiwan', 'turrell', 'v.', 'Wylie', 'melvin', 'c.', 'goldstein', 'helmut', 'Hoffman', 'suppose', 'relationship', 'one', 'suzerainty', 'Ming', 'title', 'noun_phrase', 'Tibet', 'stay', 'mugwump', 'region', 'outside', 'Ming', 'master', 'plainly', 'pay_up', 'tribute', 'jiajing', 'emperor_butterfly', '1521–1566', 'end', 'sexual_intercourse', 'Tibet']
#
# Holonyms
# ['South_China_Sea', 'Asia', 'Asia']
#
# Meronyms
# ['Taichung', 'Changtzu', 'insemination', 'Changtzu']
#
# Hyponyms
# ['Rhodes_scholar', 'account', 'bide', 'cinch', 'liquidate', 'purple_emperor', 'adjourn', 'defloration']
#
# Hypernyms
# ['student', 'speculate', 'state', 'domain', 'dynasty', 'writing', 'phrase', 'be', 'individualist', 'knowledge_domain', 'dynasty', 'know', 'pay', 'payment', 'nymphalid', 'sexual_activity']
#
# Dependency Parsing : Done
# [(('say', 'VBP'), 'cc', ('But', 'CC')),
#  (('say', 'VBP'), 'nsubj', ('scholars', 'NNS')),
#  (('scholars', 'NNS'), 'amod', ('most', 'JJS')),
#  (('scholars', 'NNS'), 'nmod', ('China', 'NNP')),
#  (('China', 'NNP'), 'case', ('outside', 'IN')),
#  (('China', 'NNP'), 'punct', (',', ',')),
#  (('China', 'NNP'), 'nmod', ('Wylie', 'NNP')),
#  (('Wylie', 'NNP'), 'case', ('such', 'JJ')),
#  (('such', 'JJ'), 'fixed', ('as', 'IN')),
#  (('Wylie', 'NNP'), 'compound', ('Turrell', 'NNP')),
#  (('Wylie', 'NNP'), 'compound', ('V.', 'NNP')),
#  (('Wylie', 'NNP'), 'punct', (',', ',')),
#  (('Wylie', 'NNP'), 'conj', ('Goldstein', 'NNP')),
#  (('Goldstein', 'NNP'), 'compound', ('Melvin', 'NNP')),
#  (('Goldstein', 'NNP'), 'compound', ('C.', 'NNP')),
#  (('Wylie', 'NNP'), 'punct', (',', ',')),
#  (('Wylie', 'NNP'), 'conj', ('Hoffman', 'NNP')),
#  (('Hoffman', 'NNP'), 'cc', ('and', 'CC')),
#  (('Hoffman', 'NNP'), 'compound', ('Helmut', 'NNP')),
#  (('say', 'VBP'), 'punct', (',', ',')),
#  (('say', 'VBP'), 'ccomp', ('one', 'CD')),
#  (('one', 'CD'), 'mark', ('that', 'IN')),
#  (('one', 'CD'), 'nsubj', ('relationship', 'NN')),
#  (('relationship', 'NN'), 'det', ('the', 'DT')),
#  (('one', 'CD'), 'cop', ('was', 'VBD')),
#  (('one', 'CD'), 'nmod', ('suzerainty', 'NN')),
#  (('suzerainty', 'NN'), 'case', ('of', 'IN')),
#  (('one', 'CD'), 'punct', (',', ',')),
#  (('one', 'CD'), 'dep', ('nominal', 'JJ')),
#  (('nominal', 'JJ'), 'mark', ('that', 'IN')),
#  (('nominal', 'JJ'), 'nsubj', ('titles', 'NNS')),
#  (('titles', 'NNS'), 'compound', ('Ming', 'NNP')),
#  (('nominal', 'JJ'), 'cop', ('were', 'VBD')),
#  (('nominal', 'JJ'), 'advmod', ('only', 'RB')),
#  (('nominal', 'JJ'), 'punct', (',', ',')),
#  (('nominal', 'JJ'), 'ccomp', ('remained', 'VBD')),
#  (('remained', 'VBD'), 'mark', ('that', 'IN')),
#  (('remained', 'VBD'), 'nsubj', ('Tibet', 'NNP')),
#  (('remained', 'VBD'), 'xcomp', ('region', 'NN')),
#  (('region', 'NN'), 'det', ('an', 'DT')),
#  (('region', 'NN'), 'amod', ('independent', 'JJ')),
#  (('region', 'NN'), 'nmod', ('control', 'NN')),
#  (('control', 'NN'), 'case', ('outside', 'IN')),
#  (('control', 'NN'), 'compound', ('Ming', 'NNP')),
#  (('remained', 'VBD'), 'punct', (',', ',')),
#  (('remained', 'VBD'), 'conj', ('paid', 'VBD')),
#  (('paid', 'VBD'), 'cc', ('and', 'CC')),
#  (('paid', 'VBD'), 'mark', ('that', 'IN')),
#  (('paid', 'VBD'), 'nsubj', ('it', 'PRP')),
#  (('paid', 'VBD'), 'advmod', ('simply', 'RB')),
#  (('paid', 'VBD'), 'obj', ('tribute', 'NN')),
#  (('paid', 'VBD'), 'obl', ('Emperor', 'NNP')),
#  (('Emperor', 'NNP'), 'case', ('until', 'IN')),
#  (('Emperor', 'NNP'), 'det', ('the', 'DT')),
#  (('Emperor', 'NNP'), 'compound', ('Jiajing', 'NNP')),
#  (('paid', 'VBD'), 'dep', ('1521', 'CD')),
#  (('1521', 'CD'), 'punct', ('(', '-LRB-')),
#  (('1521', 'CD'), 'nmod', ('1566', 'CD')),
#  (('1566', 'CD'), 'dep', ('–', 'SYM')),
#  (('1521', 'CD'), 'punct', (')', '-RRB-')),
#  (('remained', 'VBD'), 'punct', (',', ',')),
#  (('remained', 'VBD'), 'ccomp', ('ceased', 'VBD')),
#  (('ceased', 'VBD'), 'nsubj', ('who', 'WP')),
#  (('ceased', 'VBD'), 'obj', ('relations', 'NNS')),
#  (('relations', 'NNS'), 'nmod', ('Tibet', 'NNP')),
#  (('Tibet', 'NNP'), 'case', ('with', 'IN')),
#  (('say', 'VBP'), 'punct', ('.', '.'))]
#
# ------SENTENCE------
# Some scholars note that Tibetan leaders during the Ming frequently engaged in civil war and conducted their own foreign diplomacy with neighboring states such as Nepal.
#
# Word Tokenization : Done
# ['scholars', 'note', 'tibetan', 'leaders', 'ming', 'frequently', 'engaged', 'civil', 'war', 'conducted', 'foreign', 'diplomacy', 'neighboring', 'states', 'nepal']
#
# POS Tagging : Done
# [('scholars', 'NNS'), ('note', 'VBP'), ('tibetan', 'JJ'), ('leaders', 'NNS'), ('ming', 'VBG'), ('frequently', 'RB'), ('engaged', 'VBN'), ('civil', 'JJ'), ('war', 'NN'), ('conducted', 'VBD'), ('foreign', 'JJ'), ('diplomacy', 'NN'), ('neighboring', 'VBG'), ('states', 'NNS'), ('nepal', 'JJ')]
#
# Word Lemmatization : Done
# ['scholar', 'note', 'tibetan', 'leader', 'ming', 'frequently', 'engaged', 'civil', 'war', 'conducted', 'foreign', 'diplomacy', 'neighboring', 'state', 'nepal']
#
# WordNet Feature Extraction : Done
#
# Synonyms
# ['scholar', 'note', 'Tibetan', 'leadership', 'Ming', 'frequently', 'lease', 'civil', 'war', 'conduct', 'foreign', 'delicacy', 'neighbor', 'state', 'Nepal']
#
# Holonyms
# ['Asia']
#
# Meronyms
# ['Annapurna']
#
# Hyponyms
# ['Rhodes_scholar', 'high_command']
#
# Hypernyms
# ['student', 'write_down', 'Asian', 'body', 'dynasty', 'get', 'campaign', 'perform', 'tact', 'populate', 'emotional_state']
#
# Dependency Parsing : Done
# [(('note', 'VBP'), 'nsubj', ('scholars', 'NNS')),
#  (('scholars', 'NNS'), 'det', ('Some', 'DT')),
#  (('note', 'VBP'), 'ccomp', ('engaged', 'VBD')),
#  (('engaged', 'VBD'), 'mark', ('that', 'IN')),
#  (('engaged', 'VBD'), 'nsubj', ('leaders', 'NNS')),
#  (('leaders', 'NNS'), 'amod', ('Tibetan', 'JJ')),
#  (('leaders', 'NNS'), 'nmod', ('Ming', 'NNP')),
#  (('Ming', 'NNP'), 'case', ('during', 'IN')),
#  (('Ming', 'NNP'), 'det', ('the', 'DT')),
#  (('engaged', 'VBD'), 'advmod', ('frequently', 'RB')),
#  (('engaged', 'VBD'), 'obl', ('war', 'NN')),
#  (('war', 'NN'), 'case', ('in', 'IN')),
#  (('war', 'NN'), 'amod', ('civil', 'JJ')),
#  (('engaged', 'VBD'), 'conj', ('conducted', 'VBD')),
#  (('conducted', 'VBD'), 'cc', ('and', 'CC')),
#  (('conducted', 'VBD'), 'obj', ('diplomacy', 'NN')),
#  (('diplomacy', 'NN'), 'nmod:poss', ('their', 'PRP$')),
#  (('diplomacy', 'NN'), 'amod', ('own', 'JJ')),
#  (('diplomacy', 'NN'), 'amod', ('foreign', 'JJ')),
#  (('conducted', 'VBD'), 'obl', ('states', 'NNS')),
#  (('states', 'NNS'), 'case', ('with', 'IN')),
#  (('states', 'NNS'), 'compound', ('neighboring', 'NN')),
#  (('states', 'NNS'), 'nmod', ('Nepal', 'NNP')),
#  (('Nepal', 'NNP'), 'case', ('such', 'JJ')),
#  (('such', 'JJ'), 'fixed', ('as', 'IN')),
#  (('note', 'VBP'), 'punct', ('.', '.'))]
#
# ------SENTENCE------
# Some scholars underscore the commercial aspect of the Ming-Tibetan relationship, noting the Ming dynasty's shortage of horses for warfare and thus the importance of the horse trade with Tibet.
#
# Word Tokenization : Done
# ['scholars', 'underscore', 'commercial', 'aspect', 'ming-tibetan', 'relationship', 'noting', 'ming', 'dynasty', "'s", 'shortage', 'horses', 'warfare', 'thus', 'importance', 'horse', 'trade', 'tibet']
#
# POS Tagging : Done
# [('scholars', 'NNS'), ('underscore', 'VBP'), ('commercial', 'JJ'), ('aspect', 'NN'), ('ming-tibetan', 'JJ'), ('relationship', 'NN'), ('noting', 'VBG'), ('ming', 'VBG'), ('dynasty', 'NN'), ("'s", 'POS'), ('shortage', 'NN'), ('horses', 'NNS'), ('warfare', 'VBP'), ('thus', 'RB'), ('importance', 'JJ'), ('horse', 'NN'), ('trade', 'NN'), ('tibet', 'NN')]
#
# Word Lemmatization : Done
# ['scholar', 'underscore', 'commercial', 'aspect', 'ming-tibetan', 'relationship', 'noting', 'ming', 'dynasty', "'s", 'shortage', 'horse', 'warfare', 'thus', 'importance', 'horse', 'trade', 'tibet']
#
# WordNet Feature Extraction : Done
#
# Synonyms
# ['scholar', 'underscore', 'commercial', 'view', 'ming-tibetan', 'relationship', 'note', 'Ming', 'dynasty', "'s", 'deficit', 'sawhorse', 'war', 'thus', 'importance', 'sawhorse', 'trade', 'Tibet']
#
# Holonyms
# ['Asia']
#
# Meronyms
# ['Changtzu']
#
# Hyponyms
# ['Rhodes_scholar', 'infomercial', 'background', 'account', 'Bourbon', 'oxygen_deficit', 'trestle', 'drug_war', 'emphasis', 'trestle', 'close']
#
# Hypernyms
# ['student', 'stroke', 'ad', 'visual_percept', 'state', 'write_down', 'dynasty', 'family', 'insufficiency', 'framework', 'conflict', 'standing', 'framework', 'sell']
#
# Dependency Parsing : Done
# [(('underscore', 'VBP'), 'nsubj', ('scholars', 'NNS')),
#  (('scholars', 'NNS'), 'det', ('Some', 'DT')),
#  (('underscore', 'VBP'), 'obj', ('aspect', 'NN')),
#  (('aspect', 'NN'), 'det', ('the', 'DT')),
#  (('aspect', 'NN'), 'amod', ('commercial', 'JJ')),
#  (('aspect', 'NN'), 'nmod', ('relationship', 'NN')),
#  (('relationship', 'NN'), 'case', ('of', 'IN')),
#  (('relationship', 'NN'), 'det', ('the', 'DT')),
#  (('relationship', 'NN'), 'compound', ('Tibetan', 'NNP')),
#  (('Tibetan', 'NNP'), 'compound', ('Ming', 'NNP')),
#  (('Tibetan', 'NNP'), 'punct', ('-', 'HYPH')),
#  (('underscore', 'VBP'), 'punct', (',', ',')),
#  (('underscore', 'VBP'), 'conj', ('noting', 'VBG')),
#  (('noting', 'VBG'), 'obj', ('shortage', 'NN')),
#  (('shortage', 'NN'), 'nmod:poss', ('dynasty', 'NN')),
#  (('dynasty', 'NN'), 'det', ('the', 'DT')),
#  (('dynasty', 'NN'), 'compound', ('Ming', 'NNP')),
#  (('dynasty', 'NN'), 'case', ("'s", 'POS')),
#  (('shortage', 'NN'), 'nmod', ('horses', 'NNS')),
#  (('horses', 'NNS'), 'case', ('of', 'IN')),
#  (('horses', 'NNS'), 'nmod', ('warfare', 'NN')),
#  (('warfare', 'NN'), 'case', ('for', 'IN')),
#  (('underscore', 'VBP'), 'conj', ('importance', 'NN')),
#  (('importance', 'NN'), 'cc', ('and', 'CC')),
#  (('importance', 'NN'), 'advmod', ('thus', 'RB')),
#  (('importance', 'NN'), 'det', ('the', 'DT')),
#  (('importance', 'NN'), 'nmod', ('trade', 'NN')),
#  (('trade', 'NN'), 'case', ('of', 'IN')),
#  (('trade', 'NN'), 'det', ('the', 'DT')),
#  (('trade', 'NN'), 'compound', ('horse', 'NN')),
#  (('trade', 'NN'), 'nmod', ('Tibet', 'NNP')),
#  (('Tibet', 'NNP'), 'case', ('with', 'IN')),
#  (('underscore', 'VBP'), 'punct', ('.', '.'))]
#
# ------SENTENCE------
# Others argue that the significant religious nature of the relationship of the Ming court with Tibetan lamas is underrepresented in modern scholarship.
#
# Word Tokenization : Done
# ['others', 'argue', 'significant', 'religious', 'nature', 'relationship', 'ming', 'court', 'tibetan', 'lamas', 'underrepresented', 'modern', 'scholarship']
#
# POS Tagging : Done
# [('others', 'NNS'), ('argue', 'VBP'), ('significant', 'JJ'), ('religious', 'JJ'), ('nature', 'NN'), ('relationship', 'NN'), ('ming', 'VBG'), ('court', 'NN'), ('tibetan', 'NN'), ('lamas', 'NN'), ('underrepresented', 'JJ'), ('modern', 'JJ'), ('scholarship', 'NN')]
#
# Word Lemmatization : Done
# ['others', 'argue', 'significant', 'religious', 'nature', 'relationship', 'ming', 'court', 'tibetan', 'lama', 'underrepresented', 'modern', 'scholarship']
#
# WordNet Feature Extraction : Done
#
# Synonyms
# ['others', 'argue', 'significant', 'religious', 'nature', 'relationship', 'Ming', 'motor_hotel', 'Tibetan', 'lama', 'underrepresented', 'Modern', 'scholarship']
#
# Holonyms
# []
#
# Meronyms
# []
#
# Hyponyms
# ['Benedictine', 'account', 'motel', 'Dalai_Lama']
#
# Hypernyms
# ['present', 'religious_person', 'type', 'state', 'dynasty', 'hotel', 'Asian', 'priest', 'aid']
#
# Dependency Parsing : Done
# [(('argue', 'VBP'), 'nsubj', ('Others', 'NNS')),
#  (('argue', 'VBP'), 'ccomp', ('underrepresented', 'JJ')),
#  (('underrepresented', 'JJ'), 'mark', ('that', 'IN')),
#  (('underrepresented', 'JJ'), 'nsubj', ('nature', 'NN')),
#  (('nature', 'NN'), 'det', ('the', 'DT')),
#  (('nature', 'NN'), 'amod', ('significant', 'JJ')),
#  (('nature', 'NN'), 'amod', ('religious', 'JJ')),
#  (('nature', 'NN'), 'nmod', ('relationship', 'NN')),
#  (('relationship', 'NN'), 'case', ('of', 'IN')),
#  (('relationship', 'NN'), 'det', ('the', 'DT')),
#  (('relationship', 'NN'), 'nmod', ('court', 'NN')),
#  (('court', 'NN'), 'case', ('of', 'IN')),
#  (('court', 'NN'), 'det', ('the', 'DT')),
#  (('court', 'NN'), 'compound', ('Ming', 'NNP')),
#  (('relationship', 'NN'), 'nmod', ('lamas', 'NNS')),
#  (('lamas', 'NNS'), 'case', ('with', 'IN')),
#  (('lamas', 'NNS'), 'amod', ('Tibetan', 'JJ')),
#  (('underrepresented', 'JJ'), 'cop', ('is', 'VBZ')),
#  (('underrepresented', 'JJ'), 'obl', ('scholarship', 'NN')),
#  (('scholarship', 'NN'), 'case', ('in', 'IN')),
#  (('scholarship', 'NN'), 'amod', ('modern', 'JJ')),
#  (('argue', 'VBP'), 'punct', ('.', '.'))]
#
# ------SENTENCE------
# In hopes of reviving the unique relationship of the earlier Mongol leader Kublai Khan (r. 1260–1294) and his spiritual superior Drogön Chögyal Phagpa (1235–1280) of the Sakya school of Tibetan Buddhism, the Yongle Emperor (r. 1402–1424) made a concerted effort to build a secular and religious alliance with Deshin Shekpa (1384–1415), the Karmapa of the Karma Kagyu school.
#
# Word Tokenization : Done
# ['hopes', 'reviving', 'unique', 'relationship', 'earlier', 'mongol', 'leader', 'kublai', 'khan', 'r.', '1260–1294', 'spiritual', 'superior', 'drogön', 'chögyal', 'phagpa', '1235–1280', 'sakya', 'school', 'tibetan', 'buddhism', 'yongle', 'emperor', 'r.', '1402–1424', 'made', 'concerted', 'effort', 'build', 'secular', 'religious', 'alliance', 'deshin', 'shekpa', '1384–1415', 'karmapa', 'karma', 'kagyu', 'school']
#
# POS Tagging : Done
# [('hopes', 'NNS'), ('reviving', 'VBG'), ('unique', 'JJ'), ('relationship', 'NN'), ('earlier', 'RBR'), ('mongol', 'JJ'), ('leader', 'NN'), ('kublai', 'NN'), ('khan', 'VBD'), ('r.', 'JJ'), ('1260–1294', 'CD'), ('spiritual', 'JJ'), ('superior', 'JJ'), ('drogön', 'NN'), ('chögyal', 'NN'), ('phagpa', 'NN'), ('1235–1280', 'CD'), ('sakya', 'JJ'), ('school', 'NN'), ('tibetan', 'JJ'), ('buddhism', 'NN'), ('yongle', 'NN'), ('emperor', 'NN'), ('r.', 'NN'), ('1402–1424', 'CD'), ('made', 'VBD'), ('concerted', 'JJ'), ('effort', 'NN'), ('build', 'VB'), ('secular', 'JJ'), ('religious', 'JJ'), ('alliance', 'NN'), ('deshin', 'NN'), ('shekpa', 'VBD'), ('1384–1415', 'CD'), ('karmapa', 'NN'), ('karma', 'NN'), ('kagyu', 'VBD'), ('school', 'NN')]
#
# Word Lemmatization : Done
# ['hope', 'reviving', 'unique', 'relationship', 'earlier', 'mongol', 'leader', 'kublai', 'khan', 'r.', '1260–1294', 'spiritual', 'superior', 'drogön', 'chögyal', 'phagpa', '1235–1280', 'sakya', 'school', 'tibetan', 'buddhism', 'yongle', 'emperor', 'r.', '1402–1424', 'made', 'concerted', 'effort', 'build', 'secular', 'religious', 'alliance', 'deshin', 'shekpa', '1384–1415', 'karmapa', 'karma', 'kagyu', 'school']
#
# WordNet Feature Extraction : Done
#
# Synonyms
# ['hope', 'revive', 'unique', 'relationship', 'early', 'Mongol', 'leader', 'kublai', 'khan', 'r.', '1260–1294', 'spiritual', 'victor', 'drogön', 'chögyal', 'phagpa', '1235–1280', 'sakya', 'school', 'Tibetan', 'Buddhism', 'yongle', 'emperor_butterfly', 'r.', '1402–1424', 'take', 'concerted', 'feat', 'human_body', 'profane', 'religious', 'alliance', 'deshin', 'shekpa', '1384–1415', 'karmapa', 'karma', 'kagyu', 'school']
#
# Holonyms
# ['homo']
#
# Meronyms
# []
#
# Hyponyms
# ['republish', 'account', 'Khalkha', 'aristocrat', 'conqueror', 'Hinayana', 'purple_emperor', 'derring-do', 'adult_body', 'Benedictine']
#
# Hypernyms
# ['anticipation', 'regenerate', 'state', 'Oriental', 'person', 'ruler', 'religious_song', 'combatant', 'swim', 'Asian', 'religion', 'nymphalid', 'head', 'accomplishment', 'body', 'religious_person', 'treaty', 'destiny', 'swim']
#
# Dependency Parsing : Done
# [(('made', 'VBD'), 'obl', ('hopes', 'NNS')),
#  (('hopes', 'NNS'), 'case', ('In', 'IN')),
#  (('hopes', 'NNS'), 'nmod', ('relationship', 'NN')),
#  (('relationship', 'NN'), 'case', ('of', 'IN')),
#  (('relationship', 'NN'), 'amod', ('reviving', 'VBG')),
#  (('relationship', 'NN'), 'det', ('the', 'DT')),
#  (('relationship', 'NN'), 'amod', ('unique', 'JJ')),
#  (('relationship', 'NN'), 'nmod', ('Khan', 'NNP')),
#  (('Khan', 'NNP'), 'case', ('of', 'IN')),
#  (('Khan', 'NNP'), 'det', ('the', 'DT')),
#  (('Khan', 'NNP'), 'amod', ('earlier', 'JJR')),
#  (('Khan', 'NNP'), 'compound', ('leader', 'NN')),
#  (('leader', 'NN'), 'compound', ('Mongol', 'NNP')),
#  (('Khan', 'NNP'), 'compound', ('Kublai', 'NNP')),
#  (('Khan', 'NNP'), 'punct', ('(', '-LRB-')),
#  (('Khan', 'NNP'), 'dep', ('1260', 'CD')),
#  (('1260', 'CD'), 'dep', ('r.', 'NN')),
#  (('1260', 'CD'), 'nmod', ('1294', 'CD')),
#  (('1294', 'CD'), 'dep', ('–', 'SYM')),
#  (('Khan', 'NNP'), 'punct', (')', '-RRB-')),
#  (('Khan', 'NNP'), 'conj', ('Phagpa', 'NNP')),
#  (('Phagpa', 'NNP'), 'cc', ('and', 'CC')),
#  (('Phagpa', 'NNP'), 'nmod:poss', ('his', 'PRP$')),
#  (('Phagpa', 'NNP'), 'amod', ('spiritual', 'JJ')),
#  (('Phagpa', 'NNP'), 'amod', ('superior', 'JJ')),
#  (('Phagpa', 'NNP'), 'compound', ('Drogön', 'NNP')),
#  (('Phagpa', 'NNP'), 'compound', ('Chögyal', 'NNP')),
#  (('Phagpa', 'NNP'), 'dep', ('1235', 'CD')),
#  (('1235', 'CD'), 'punct', ('(', '-LRB-')),
#  (('1235', 'CD'), 'nmod', ('1280', 'CD')),
#  (('1280', 'CD'), 'dep', ('–', 'SYM')),
#  (('1235', 'CD'), 'punct', (')', '-RRB-')),
#  (('Khan', 'NNP'), 'nmod', ('school', 'NN')),
#  (('school', 'NN'), 'case', ('of', 'IN')),
#  (('school', 'NN'), 'det', ('the', 'DT')),
#  (('school', 'NN'), 'compound', ('Sakya', 'NNP')),
#  (('school', 'NN'), 'nmod', ('Buddhism', 'NNP')),
#  (('Buddhism', 'NNP'), 'case', ('of', 'IN')),
#  (('Buddhism', 'NNP'), 'compound', ('Tibetan', 'NNP')),
#  (('Khan', 'NNP'), 'punct', (',', ',')),
#  (('Khan', 'NNP'), 'appos', ('Emperor', 'NNP')),
#  (('Emperor', 'NNP'), 'det', ('the', 'DT')),
#  (('Emperor', 'NNP'), 'compound', ('Yongle', 'NNP')),
#  (('Khan', 'NNP'), 'punct', ('(', '-LRB-')),
#  (('Khan', 'NNP'), 'dep', ('1402', 'CD')),
#  (('1402', 'CD'), 'dep', ('r.', 'NN')),
#  (('1402', 'CD'), 'nmod', ('1424', 'CD')),
#  (('1424', 'CD'), 'dep', ('–', 'SYM')),
#  (('Khan', 'NNP'), 'punct', (')', '-RRB-')),
#  (('made', 'VBD'), 'obj', ('effort', 'NN')),
#  (('effort', 'NN'), 'det', ('a', 'DT')),
#  (('effort', 'NN'), 'amod', ('concerted', 'JJ')),
#  (('made', 'VBD'), 'xcomp', ('build', 'VB')),
#  (('build', 'VB'), 'mark', ('to', 'TO')),
#  (('build', 'VB'), 'obj', ('alliance', 'NN')),
#  (('alliance', 'NN'), 'det', ('a', 'DT')),
#  (('alliance', 'NN'), 'amod', ('secular', 'JJ')),
#  (('secular', 'JJ'), 'conj', ('religious', 'JJ')),
#  (('religious', 'JJ'), 'cc', ('and', 'CC')),
#  (('alliance', 'NN'), 'nmod', ('Shekpa', 'NNP')),
#  (('Shekpa', 'NNP'), 'case', ('with', 'IN')),
#  (('Shekpa', 'NNP'), 'compound', ('Deshin', 'NNP')),
#  (('Shekpa', 'NNP'), 'appos', ('1384', 'CD')),
#  (('1384', 'CD'), 'punct', ('(', '-LRB-')),
#  (('1384', 'CD'), 'nmod', ('1415', 'CD')),
#  (('1415', 'CD'), 'dep', ('–', 'SYM')),
#  (('1384', 'CD'), 'punct', (')', '-RRB-')),
#  (('Shekpa', 'NNP'), 'punct', (',', ',')),
#  (('Shekpa', 'NNP'), 'appos', ('Karmapa', 'NNP')),
#  (('Karmapa', 'NNP'), 'det', ('the', 'DT')),
#  (('Karmapa', 'NNP'), 'nmod', ('school', 'NN')),
#  (('school', 'NN'), 'case', ('of', 'IN')),
#  (('school', 'NN'), 'det', ('the', 'DT')),
#  (('school', 'NN'), 'compound', ('Kagyu', 'NNP')),
#  (('Kagyu', 'NNP'), 'compound', ('Karma', 'NNP')),
#  (('made', 'VBD'), 'punct', ('.', '.'))]
#
# ------SENTENCE------
# However, the Yongle Emperor's attempts were unsuccessful.
#
# Word Tokenization : Done
# ['however', 'yongle', 'emperor', "'s", 'attempts', 'unsuccessful']
# POS Tagging : Done
# [('however', 'RB'), ('yongle', 'JJ'), ('emperor', 'NN'), ("'s", 'POS'), ('attempts', 'NNS'), ('unsuccessful', 'JJ')]
#
# Word Lemmatization : Done
# ['however', 'yongle', 'emperor', "'s", 'attempt', 'unsuccessful']
#
# WordNet Feature Extraction : Done
#
# Synonyms
# ['however', 'yongle', 'emperor_butterfly', "'s", 'undertake', 'unsuccessful']
#
# Holonyms
# []
#
# Meronyms
# []
#
# Hyponyms
# ['purple_emperor']
#
# Hypernyms
# ['nymphalid', 'initiate']
#
# Dependency Parsing : Done
# [(('unsuccessful', 'JJ'), 'advmod', ('However', 'RB')),
#  (('unsuccessful', 'JJ'), 'punct', (',', ',')),
#  (('unsuccessful', 'JJ'), 'nsubj', ('attempts', 'NNS')),
#  (('attempts', 'NNS'), 'nmod:poss', ('Emperor', 'NNP')),
#  (('Emperor', 'NNP'), 'det', ('the', 'DT')),
#  (('Emperor', 'NNP'), 'compound', ('Yongle', 'NNP')),
#  (('Emperor', 'NNP'), 'case', ("'s", 'POS')),
#  (('unsuccessful', 'JJ'), 'cop', ('were', 'VBD')),
#  (('unsuccessful', 'JJ'), 'punct', ('.', '.'))]
#
# ------SENTENCE------
# The Ming initiated sporadic armed intervention in Tibet during the 14th century, but did not garrison permanent troops there.
#
# Word Tokenization : Done
# ['ming', 'initiated', 'sporadic', 'armed', 'intervention', 'tibet', '14th', 'century', 'garrison', 'permanent', 'troops']
#
# POS Tagging : Done
# [('ming', 'VBG'), ('initiated', 'VBN'), ('sporadic', 'JJ'), ('armed', 'VBN'), ('intervention', 'NN'), ('tibet', 'NN'), ('14th', 'JJ'), ('century', 'NN'), ('garrison', 'NN'), ('permanent', 'JJ'), ('troops', 'NNS')]
#
# Word Lemmatization : Done
# ['ming', 'initiated', 'sporadic', 'armed', 'intervention', 'tibet', '14th', 'century', 'garrison', 'permanent', 'troop']
#
# WordNet Feature Extraction : Done
#
# Synonyms
# ['Ming', 'broach', 'sporadic', 'arm', 'treatment', 'Tibet', 'fourteenth', 'century', 'garrison', 'permanent_wave', 'troop']
#
# Holonyms
# ['Asia', 'millennium']
#
# Meronyms
# ['remedy', 'Changtzu', 'decade']
#
# Hyponyms
# ['cover', 'forearm', 'acupressure', 'quattrocento']
#
# Hypernyms
# ['dynasty', 'hash_out', 'care', 'time_period', 'station', 'wave', 'march']
#
# Dependency Parsing : Done
# [(('initiated', 'VBD'), 'nsubj', ('Ming', 'NNP')),
#  (('Ming', 'NNP'), 'det', ('The', 'DT')),
#  (('initiated', 'VBD'), 'obj', ('intervention', 'NN')),
#  (('intervention', 'NN'), 'amod', ('sporadic', 'JJ')),
#  (('intervention', 'NN'), 'amod', ('armed', 'JJ')),
#  (('intervention', 'NN'), 'nmod', ('Tibet', 'NNP')),
#  (('Tibet', 'NNP'), 'case', ('in', 'IN')),
#  (('initiated', 'VBD'), 'obl', ('century', 'NN')),
#  (('century', 'NN'), 'case', ('during', 'IN')),
#  (('century', 'NN'), 'det', ('the', 'DT')),
#  (('century', 'NN'), 'amod', ('14th', 'JJ')),
#  (('initiated', 'VBD'), 'punct', (',', ',')),
#  (('initiated', 'VBD'), 'conj', ('garrison', 'NN')),
#  (('garrison', 'NN'), 'cc', ('but', 'CC')),
#  (('garrison', 'NN'), 'aux', ('did', 'VBD')),
#  (('garrison', 'NN'), 'advmod', ('not', 'RB')),
#  (('garrison', 'NN'), 'obj', ('troops', 'NNS')),
#  (('troops', 'NNS'), 'amod', ('permanent', 'JJ')),
#  (('garrison', 'NN'), 'advmod', ('there', 'RB')),
#  (('initiated', 'VBD'), 'punct', ('.', '.'))]
#
# ------SENTENCE------
# At times the Tibetans also used armed resistance against Ming forays.
#
# Word Tokenization : Done
# ['times', 'tibetans', 'also', 'used', 'armed', 'resistance', 'ming', 'forays']
#
# POS Tagging : Done
# [('times', 'NNS'), ('tibetans', 'NNS'), ('also', 'RB'), ('used', 'VBD'), ('armed', 'VBN'), ('resistance', 'NN'), ('ming', 'NN'), ('forays', 'NNS')]
#
# Word Lemmatization : Done
# ['time', 'tibetan', 'also', 'used', 'armed', 'resistance', 'ming', 'foray']
#
# WordNet Feature Extraction : Done
#
# Synonyms
# ['times', 'Tibetan', 'besides', 'use', 'arm', 'underground', 'Ming', 'foray']
#
# Holonyms
# []
#
# Meronyms
# []
#
# Hyponyms
# ['modern_times', 'address', 'forearm', 'Maquis', 'air_raid']
#
# Hypernyms
# ['time_period', 'Asian', 'revolutionary_group', 'dynasty', 'penetration']
#
# Dependency Parsing : Done
# [(('used', 'VBD'), 'obl', ('times', 'NNS')),
#  (('times', 'NNS'), 'case', ('At', 'IN')),
#  (('used', 'VBD'), 'nsubj', ('Tibetans', 'NNPS')),
#  (('Tibetans', 'NNPS'), 'det', ('the', 'DT')),
#  (('used', 'VBD'), 'advmod', ('also', 'RB')),
#  (('used', 'VBD'), 'obj', ('resistance', 'NN')),
#  (('resistance', 'NN'), 'amod', ('armed', 'JJ')),
#  (('resistance', 'NN'), 'nmod', ('forays', 'NNS')),
#  (('forays', 'NNS'), 'case', ('against', 'IN')),
#  (('forays', 'NNS'), 'compound', ('Ming', 'NNP')),
#  (('used', 'VBD'), 'punct', ('.', '.'))]
#
# ------SENTENCE------
# The Wanli Emperor (r. 1572–1620) made attempts to reestablish Sino-Tibetan relations after the Mongol-Tibetan alliance initiated in 1578, which affected the foreign policy of the subsequent Qing dynasty (1644–1912) of China in their support for the Dalai Lama of the Gelug school.
#
# Word Tokenization : Done
# ['wanli', 'emperor', 'r.', '1572–1620', 'made', 'attempts', 'reestablish', 'sino-tibetan', 'relations', 'mongol-tibetan', 'alliance', 'initiated', '1578', 'affected', 'foreign', 'policy', 'subsequent', 'qing', 'dynasty', '1644–1912', 'china', 'support', 'dalai', 'lama', 'gelug', 'school']
#
# POS Tagging : Done
# [('wanli', 'NN'), ('emperor', 'NN'), ('r.', 'NN'), ('1572–1620', 'CD'), ('made', 'VBD'), ('attempts', 'NNS'), ('reestablish', 'JJ'), ('sino-tibetan', 'JJ'), ('relations', 'NNS'), ('mongol-tibetan', 'JJ'), ('alliance', 'NN'), ('initiated', 'JJ'), ('1578', 'CD'), ('affected', 'JJ'), ('foreign', 'JJ'), ('policy', 'NN'), ('subsequent', 'JJ'), ('qing', 'VBG'), ('dynasty', 'JJ'), ('1644–1912', 'CD'), ('china', 'JJ'), ('support', 'NN'), ('dalai', 'NN'), ('lama', 'NN'), ('gelug', 'NN'), ('school', 'NN')]
#
# Word Lemmatization : Done
# ['wanli', 'emperor', 'r.', '1572–1620', 'made', 'attempt', 'reestablish', 'sino-tibetan', 'relation', 'mongol-tibetan', 'alliance', 'initiated', '1578', 'affected', 'foreign', 'policy', 'subsequent', 'qing', 'dynasty', '1644–1912', 'china', 'support', 'dalai', 'lama', 'gelug', 'school']
#
# WordNet Feature Extraction : Done
#
# Synonyms
# ['wanli', 'emperor_butterfly', 'r.', '1572–1620', 'take', 'undertake', 'restore', 'Sino-Tibetan', 'sexual_intercourse', 'mongol-tibetan', 'alliance', 'broach', '1578', 'moved', 'foreign', 'policy', 'subsequent', 'Qing', 'dynasty', '1644–1912', 'Taiwan', 'support', 'dalai', 'lama', 'gelug', 'school']
#
# Holonyms
# ['South_China_Sea']
#
# Meronyms
# ['insemination', 'Taichung']
#
# Hyponyms
# ['purple_emperor', 'redeem', 'Kadai', 'defloration', 'cover', 'clericalism', 'Bourbon', 'Dalai_Lama']
#
# Hypernyms
# ['nymphalid', 'head', 'initiate', 'change', 'natural_language', 'sexual_activity', 'treaty', 'hash_out', 'argumentation', 'dynasty', 'family', 'act', 'priest', 'swim']
#
# Dependency Parsing : Done
# [(('made', 'VBN'), 'nsubj', ('Emperor', 'NNP')),
#  (('Emperor', 'NNP'), 'det', ('The', 'DT')),
#  (('Emperor', 'NNP'), 'compound', ('Wanli', 'NNP')),
#  (('Emperor', 'NNP'), 'appos', ('r.', 'NN')),
#  (('r.', 'NN'), 'punct', ('(', '-LRB-')),
#  (('r.', 'NN'), 'nummod', ('1572', 'CD')),
#  (('r.', 'NN'), 'dep', ('–', 'SYM')),
#  (('r.', 'NN'), 'nummod', ('1620', 'CD')),
#  (('r.', 'NN'), 'punct', (')', '-RRB-')),
#  (('made', 'VBN'), 'obj', ('attempts', 'NNS')),
#  (('made', 'VBN'), 'xcomp', ('reestablish', 'VB')),
#  (('reestablish', 'VB'), 'mark', ('to', 'TO')),
#  (('reestablish', 'VB'), 'obj', ('relations', 'NNS')),
#  (('relations', 'NNS'), 'amod', ('Tibetan', 'JJ')),
#  (('Tibetan', 'JJ'), 'amod', ('Sino', 'JJ')),
#  (('Tibetan', 'JJ'), 'punct', ('-', 'HYPH')),
#  (('reestablish', 'VB'), 'advcl', ('initiated', 'VBN')),
#  (('initiated', 'VBN'), 'mark', ('after', 'IN')),
#  (('initiated', 'VBN'), 'nsubj', ('alliance', 'NN')),
#  (('alliance', 'NN'), 'det', ('the', 'DT')),
#  (('alliance', 'NN'), 'compound', ('Tibetan', 'NNP')),
#  (('Tibetan', 'NNP'), 'compound', ('Mongol', 'NNP')),
#  (('Tibetan', 'NNP'), 'punct', ('-', 'HYPH')),
#  (('initiated', 'VBN'), 'obl', ('1578', 'CD')),
#  (('1578', 'CD'), 'case', ('in', 'IN')),
#  (('initiated', 'VBN'), 'punct', (',', ',')),
#  (('initiated', 'VBN'), 'dep', ('affected', 'VBD')),
#  (('affected', 'VBD'), 'nsubj', ('which', 'WDT')),
#  (('affected', 'VBD'), 'obj', ('policy', 'NN')),
#  (('policy', 'NN'), 'det', ('the', 'DT')),
#  (('policy', 'NN'), 'amod', ('foreign', 'JJ')),
#  (('policy', 'NN'), 'nmod', ('dynasty', 'NN')),
#  (('dynasty', 'NN'), 'case', ('of', 'IN')),
#  (('dynasty', 'NN'), 'det', ('the', 'DT')),
#  (('dynasty', 'NN'), 'amod', ('subsequent', 'JJ')),
#  (('dynasty', 'NN'), 'compound', ('Qing', 'NNP')),
#  (('dynasty', 'NN'), 'dep', ('1644', 'CD')),
#  (('1644', 'CD'), 'punct', ('(', '-LRB-')),
#  (('1644', 'CD'), 'nmod', ('1912', 'CD')),
#  (('1912', 'CD'), 'dep', ('–', 'SYM')),
#  (('1644', 'CD'), 'punct', (')', '-RRB-')),
#  (('dynasty', 'NN'), 'nmod', ('China', 'NNP')),
#  (('China', 'NNP'), 'case', ('of', 'IN')),
#  (('affected', 'VBD'), 'obl', ('support', 'NN')),
#  (('support', 'NN'), 'case', ('in', 'IN')),
#  (('support', 'NN'), 'nmod:poss', ('their', 'PRP$')),
#  (('support', 'NN'), 'nmod', ('Lama', 'NNP')),
#  (('Lama', 'NNP'), 'case', ('for', 'IN')),
#  (('Lama', 'NNP'), 'det', ('the', 'DT')),
#  (('Lama', 'NNP'), 'compound', ('Dalai', 'NNP')),
#  (('Lama', 'NNP'), 'nmod', ('school', 'NN')),
#  (('school', 'NN'), 'case', ('of', 'IN')),
#  (('school', 'NN'), 'det', ('the', 'DT')),
#  (('school', 'NN'), 'compound', ('Gelug', 'NNP')),
#  (('made', 'VBN'), 'punct', ('.', '.'))]
#
# ------SENTENCE------
# By the late 16th century, the Mongols were successful armed protectors of the Gelug Dalai Lama, after increasing their presence in the Amdo region.
#
# Word Tokenization : Done
# ['late', '16th', 'century', 'mongols', 'successful', 'armed', 'protectors', 'gelug', 'dalai', 'lama', 'increasing', 'presence', 'amdo', 'region']
#
# POS Tagging : Done
# [('late', 'RB'), ('16th', 'JJ'), ('century', 'NN'), ('mongols', 'NNS'), ('successful', 'JJ'), ('armed', 'VBD'), ('protectors', 'NNS'), ('gelug', 'VBP'), ('dalai', 'JJ'), ('lama', 'NN'), ('increasing', 'VBG'), ('presence', 'NN'), ('amdo', 'NN'), ('region', 'NN')]
#
# Word Lemmatization : Done
# ['late', '16th', 'century', 'mongol', 'successful', 'armed', 'protector', 'gelug', 'dalai', 'lama', 'increasing', 'presence', 'amdo', 'region']
#
# WordNet Feature Extraction : Done
#
# Synonyms
# ['late', 'sixteenth', 'century', 'Mongol', 'successful', 'arm', 'defender', 'gelug', 'dalai', 'lama', 'increasing', 'presence', 'amdo', 'region']
#
# Holonyms
# ['millennium']
#
# Meronyms
# ['decade']
#
# Hyponyms
# ['quattrocento', 'Khalkha', 'forearm', 'admonisher', 'Dalai_Lama']
#
# Hypernyms
# ['time_period', 'Oriental', 'preserver', 'priest', 'attendance', 'knowledge_domain']
#
# Dependency Parsing : Done
# [(('protectors', 'NNS'), 'obl', ('century', 'NN')),
#  (('century', 'NN'), 'case', ('By', 'IN')),
#  (('century', 'NN'), 'det', ('the', 'DT')),
#  (('century', 'NN'), 'amod', ('late', 'JJ')),
#  (('century', 'NN'), 'amod', ('16th', 'JJ')),
#  (('protectors', 'NNS'), 'punct', (',', ',')),
#  (('protectors', 'NNS'), 'nsubj', ('Mongols', 'NNPS')),
#  (('Mongols', 'NNPS'), 'det', ('the', 'DT')),
#  (('protectors', 'NNS'), 'cop', ('were', 'VBD')),
#  (('protectors', 'NNS'), 'amod', ('successful', 'JJ')),
#  (('protectors', 'NNS'), 'amod', ('armed', 'JJ')),
#  (('protectors', 'NNS'), 'nmod', ('Lama', 'NNP')),
#  (('Lama', 'NNP'), 'case', ('of', 'IN')),
#  (('Lama', 'NNP'), 'det', ('the', 'DT')),
#  (('Lama', 'NNP'), 'compound', ('Gelug', 'NNP')),
#  (('Lama', 'NNP'), 'compound', ('Dalai', 'NNP')),
#  (('protectors', 'NNS'), 'punct', (',', ',')),
#  (('protectors', 'NNS'), 'dep', ('after', 'IN')),
#  (('after', 'IN'), 'dep', ('increasing', 'VBG')),
#  (('increasing', 'VBG'), 'obj', ('presence', 'NN')),
#  (('presence', 'NN'), 'nmod:poss', ('their', 'PRP$')),
#  (('presence', 'NN'), 'nmod', ('region', 'NN')),
#  (('region', 'NN'), 'case', ('in', 'IN')),
#  (('region', 'NN'), 'det', ('the', 'DT')),
#  (('region', 'NN'), 'compound', ('Amdo', 'NNP')),
#  (('protectors', 'NNS'), 'punct', ('.', '.'))]
#
# ------SENTENCE------
# This culminated in Güshi Khan's (1582–1655) conquest of Tibet from 1637–1642 and the establishment of the Ganden Phodrang regime by the 5th Dalai Lama with his help.
#
# Word Tokenization : Done
# ['culminated', 'güshi', 'khan', "'s", '1582–1655', 'conquest', 'tibet', '1637–1642', 'establishment', 'ganden', 'phodrang', 'regime', '5th', 'dalai', 'lama', 'help']
#
# POS Tagging : Done
# [('culminated', 'VBN'), ('güshi', 'NN'), ('khan', 'NN'), ("'s", 'POS'), ('1582–1655', 'CD'), ('conquest', 'NN'), ('tibet', 'NN'), ('1637–1642', 'CD'), ('establishment', 'NN'), ('ganden', 'NN'), ('phodrang', 'NN'), ('regime', 'NN'), ('5th', 'CD'), ('dalai', 'NN'), ('lama', 'NN'), ('help', 'NN')]
#
# Word Lemmatization : Done
# ['culminated', 'güshi', 'khan', "'s", '1582–1655', 'conquest', 'tibet', '1637–1642', 'establishment', 'ganden', 'phodrang', 'regime', '5th', 'dalai', 'lama', 'help']
#
# WordNet Feature Extraction : Done
#
# Synonyms
# ['culminate', 'güshi', 'khan', "'s", '1582–1655', 'seduction', 'Tibet', '1637–1642', 'institution', 'ganden', 'phodrang', 'regimen', 'fifth', 'dalai', 'lama', 'help_oneself']
#
# Holonyms
# ['Asia']
#
# Meronyms
# ['Changtzu']
#
# Hyponyms
# ['sexual_conquest', 'academy', 'Dalai_Lama']
#
# Hypernyms
# ['form', 'ruler', 'success', 'organization', 'plan', 'priest', 'refrain']
#
# Dependency Parsing : Done
# [(('culminated', 'VBN'), 'nsubj', ('This', 'DT')),
#  (('culminated', 'VBN'), 'obl', ('conquest', 'NN')),
#  (('conquest', 'NN'), 'case', ('in', 'IN')),
#  (('conquest', 'NN'), 'compound', ('Khan', 'NNP')),
#  (('Khan', 'NNP'), 'compound', ('Güshi', 'NNP')),
#  (('Khan', 'NNP'), 'case', ("'s", 'POS')),
#  (('Khan', 'NNP'), 'dep', ('1582', 'CD')),
#  (('1582', 'CD'), 'punct', ('(', '-LRB-')),
#  (('1582', 'CD'), 'nmod', ('1655', 'CD')),
#  (('1655', 'CD'), 'dep', ('–', 'SYM')),
#  (('1582', 'CD'), 'punct', (')', '-RRB-')),
#  (('conquest', 'NN'), 'nmod', ('Tibet', 'NNP')),
#  (('Tibet', 'NNP'), 'case', ('of', 'IN')),
#  (('culminated', 'VBN'), 'obl', ('1637', 'CD')),
#  (('1637', 'CD'), 'case', ('from', 'IN')),
#  (('1637', 'CD'), 'nmod', ('1642', 'CD')),
#  (('1642', 'CD'), 'dep', ('–', 'SYM')),
#  (('1637', 'CD'), 'conj', ('establishment', 'NN')),
#  (('establishment', 'NN'), 'cc', ('and', 'CC')),
#  (('establishment', 'NN'), 'det', ('the', 'DT')),
#  (('establishment', 'NN'), 'nmod', ('regime', 'NN')),
#  (('regime', 'NN'), 'case', ('of', 'IN')),
#  (('regime', 'NN'), 'det', ('the', 'DT')),
#  (('regime', 'NN'), 'compound', ('Phodrang', 'NNP')),
#  (('Phodrang', 'NNP'), 'compound', ('Ganden', 'NNP')),
#  (('establishment', 'NN'), 'nmod', ('Lama', 'NNP')),
#  (('Lama', 'NNP'), 'case', ('by', 'IN')),
#  (('Lama', 'NNP'), 'det', ('the', 'DT')),
#  (('Lama', 'NNP'), 'amod', ('5th', 'JJ')),
#  (('Lama', 'NNP'), 'compound', ('Dalai', 'NNP')),
#  (('establishment', 'NN'), 'nmod', ('help', 'NN')),
#  (('help', 'NN'), 'case', ('with', 'IN')),
#  (('help', 'NN'), 'nmod:poss', ('his', 'PRP$')),
# ...
#
# Word Lemmatization : Done
# ['according', 'tibetologist', 'john', 'power', 'tibetan', 'source', 'counter', 'narrative', 'title', 'granted', 'chinese', 'tibetan', 'various', 'title', 'tibetan', 'gave', 'chinese', 'emperor', 'official']
#
# WordNet Feature Extraction : Done
#
# Synonyms
# ['harmonize', 'tibetologist', 'whoremaster', 'world_power', 'Tibetan', 'source', 'rejoinder', 'narrative', 'title', 'given', 'Chinese', 'Tibetan', 'versatile', 'title', 'Tibetan', 'give', 'Chinese', 'emperor_butterfly', 'official']
#
# Holonyms
# []
#
# Meronyms
# []
#
# Hyponyms
# ['blend', 'hegemon', 'origin', 'sass', 'Boxer', 'Boxer', 'purple_emperor', 'football_official']
#
# Hypernyms
# ['match', 'customer', 'state', 'Asian', 'natural_process', 'reply', 'writing', 'Asian', 'Asian', 'writing', 'Asian', 'accept', 'Asian', 'nymphalid', 'adjudicator']
#
# Dependency Parsing : Done
# [(('counter', 'VBP'), 'obl', ('Powers', 'NNP')),
#  (('Powers', 'NNP'), 'case', ('According', 'VBG')),
#  (('According', 'VBG'), 'fixed', ('to', 'IN')),
#  (('Powers', 'NNP'), 'compound', ('Tibetologist', 'NNP')),
#  (('Powers', 'NNP'), 'compound', ('John', 'NNP')),
#  (('counter', 'VBP'), 'punct', (',', ',')),
#  (('counter', 'VBP'), 'nsubj', ('sources', 'NNS')),
#  (('sources', 'NNS'), 'compound', ('Tibetan', 'NNP')),
#  (('counter', 'VBP'), 'dep', ('granted', 'VBN')),
#  (('granted', 'VBN'), 'nsubj', ('narrative', 'NN')),
#  (('narrative', 'NN'), 'det', ('this', 'DT')),
#  (('narrative', 'NN'), 'nmod', ('titles', 'NNS')),
#  (('titles', 'NNS'), 'case', ('of', 'IN')),
#  (('granted', 'VBN'), 'obl', ('Chinese', 'NNPS')),
#  (('Chinese', 'NNPS'), 'case', ('by', 'IN')),
#  (('Chinese', 'NNPS'), 'det', ('the', 'DT')),
#  (('granted', 'VBN'), 'obl', ('Tibetans', 'NNPS')),
#  (('Tibetans', 'NNPS'), 'case', ('to', 'TO')),
#  (('Tibetans', 'NNPS'), 'nmod', ('titles', 'NNS')),
#  (('titles', 'NNS'), 'case', ('with', 'IN')),
#  (('titles', 'NNS'), 'amod', ('various', 'JJ')),
#  (('titles', 'NNS'), 'acl:relcl', ('gave', 'VBD')),
#  (('gave', 'VBD'), 'obj', ('which', 'WDT')),
#  (('gave', 'VBD'), 'nsubj', ('Tibetans', 'NNPS')),
#  (('Tibetans', 'NNPS'), 'det', ('the', 'DT')),
#  (('gave', 'VBD'), 'obl', ('emperors', 'NNS')),
#  (('emperors', 'NNS'), 'case', ('to', 'IN')),
#  (('emperors', 'NNS'), 'det', ('the', 'DT')),
#  (('emperors', 'NNS'), 'amod', ('Chinese', 'JJ')),
#  (('emperors', 'NNS'), 'conj', ('officials', 'NNS')),
#  (('officials', 'NNS'), 'cc', ('and', 'CC')),
#  (('officials', 'NNS'), 'nmod:poss', ('their', 'PRP$')),
#  (('counter', 'VBP'), 'punct', ('.', '.'))]
#
# ------SENTENCE------
# Tribute missions from Tibetan monasteries to the Chinese court brought back not only titles, but large, commercially valuable gifts which could subsequently be sold.
#
# Word Tokenization : Done
# ['tribute', 'missions', 'tibetan', 'monasteries', 'chinese', 'court', 'brought', 'back', 'titles', 'large', 'commercially', 'valuable', 'gifts', 'could', 'subsequently', 'sold']
#
# POS Tagging : Done
# [('tribute', 'JJ'), ('missions', 'NNS'), ('tibetan', 'JJ'), ('monasteries', 'NNS'), ('chinese', 'JJ'), ('court', 'NN'), ('brought', 'VBD'), ('back', 'RP'), ('titles', 'NNS'), ('large', 'JJ'), ('commercially', 'RB'), ('valuable', 'JJ'), ('gifts', 'NNS'), ('could', 'MD'), ('subsequently', 'RB'), ('sold', 'VB')]
#
# Word Lemmatization : Done
# ['tribute', 'mission', 'tibetan', 'monastery', 'chinese', 'court', 'brought', 'back', 'title', 'large', 'commercially', 'valuable', 'gift', 'could', 'subsequently', 'sold']
#
# WordNet Feature Extraction : Done
#
# Synonyms
# ['tribute', 'mission', 'Tibetan', 'monastery', 'Chinese', 'motor_hotel', 'lend', 'binding', 'title', 'large', 'commercially', 'valuable', 'give', 'could', 'subsequently', 'sold']
#
# Holonyms
# ['book']
#
# Meronyms
# ['cell']
#
# Hyponyms
# ["da'wah", 'abbey', 'Boxer', 'motel', 'factor', 'half_binding', 'bequeath']
#
# Hypernyms
# ['payment', 'work', 'Asian', 'religious_residence', 'Asian', 'hotel', 'change', 'protective_covering', 'writing']
# Dependency Parsing : Done
# [(('brought', 'VBD'), 'nsubj', ('missions', 'NNS')),
#  (('missions', 'NNS'), 'compound', ('Tribute', 'NN')),
#  (('missions', 'NNS'), 'nmod', ('monasteries', 'NNS')),
#  (('monasteries', 'NNS'), 'case', ('from', 'IN')),
#  (('monasteries', 'NNS'), 'amod', ('Tibetan', 'JJ')),
#  (('missions', 'NNS'), 'nmod', ('court', 'NN')),
#  (('court', 'NN'), 'case', ('to', 'IN')),
#  (('court', 'NN'), 'det', ('the', 'DT')),
#  (('court', 'NN'), 'amod', ('Chinese', 'JJ')),
#  (('brought', 'VBD'), 'advmod', ('back', 'RB')),
#  (('brought', 'VBD'), 'obj', ('titles', 'NNS')),
#  (('titles', 'NNS'), 'cc:preconj', ('only', 'RB')),
#  (('only', 'RB'), 'advmod', ('not', 'RB')),
#  (('titles', 'NNS'), 'punct', (',', ',')),
#  (('titles', 'NNS'), 'conj', ('gifts', 'NNS')),
#  (('gifts', 'NNS'), 'cc', ('but', 'CC')),
#  (('gifts', 'NNS'), 'amod', ('large', 'JJ')),
#  (('gifts', 'NNS'), 'punct', (',', ',')),
#  (('gifts', 'NNS'), 'amod', ('valuable', 'JJ')),
#  (('valuable', 'JJ'), 'advmod', ('commercially', 'RB')),
#  (('gifts', 'NNS'), 'acl:relcl', ('sold', 'VBN')),
#  (('sold', 'VBN'), 'nsubj:pass', ('which', 'WDT')),
#  (('sold', 'VBN'), 'aux', ('could', 'MD')),
#  (('sold', 'VBN'), 'advmod', ('subsequently', 'RB')),
#  (('sold', 'VBN'), 'aux:pass', ('be', 'VB')),
#  (('brought', 'VBD'), 'punct', ('.', '.'))]
#
# ------SENTENCE------
# The Ming emperors sent invitations to ruling lamas, but the lamas sent subordinates rather than coming themselves, and no Tibetan ruler ever explicitly accepted the role of being a vassal of the Ming.
#
# Word Tokenization : Done
# ['ming', 'emperors', 'sent', 'invitations', 'ruling', 'lamas', 'lamas', 'sent', 'subordinates', 'rather', 'coming', 'tibetan', 'ruler', 'ever', 'explicitly', 'accepted', 'role', 'vassal', 'ming']
#
# POS Tagging : Done
# [('ming', 'VBG'), ('emperors', 'NNS'), ('sent', 'VBD'), ('invitations', 'NNS'), ('ruling', 'VBG'), ('lamas', 'JJ'), ('lamas', 'JJ'), ('sent', 'NN'), ('subordinates', 'NNS'), ('rather', 'RB'), ('coming', 'VBG'), ('tibetan', 'VB'), ('ruler', 'NN'), ('ever', 'RB'), ('explicitly', 'RB'), ('accepted', 'VBN'), ('role', 'NN'), ('vassal', 'NN'), ('ming', 'VBG')]
#
# Word Lemmatization : Done
# ['ming', 'emperor', 'sent', 'invitation', 'ruling', 'lama', 'lama', 'sent', 'subordinate', 'rather', 'coming', 'tibetan', 'ruler', 'ever', 'explicitly', 'accepted', 'role', 'vassal', 'ming']
#
# WordNet Feature Extraction : Done
#
# Synonyms
# ['Ming', 'emperor_butterfly', 'station', 'invitation', 'rule', 'lama', 'lama', 'station', 'hyponym', 'quite', 'hail', 'Tibetan', 'ruler', 'ever', 'explicitly', 'accept', 'role', 'vassal', 'Ming']
#
# Holonyms
# []
#
# Meronyms
# []
#
# Hyponyms
# ['purple_emperor', 'fort', 'Dalai_Lama', 'Dalai_Lama', 'fort', 'basileus', 'gender_role']
#
# Hypernyms
# ['dynasty', 'nymphalid', 'move', 'allure', 'draw', 'priest', 'priest', 'move', 'word', 'be', 'Asian', 'person', 'react', 'activity', 'follower', 'dynasty']
#
# Dependency Parsing : Done
# [(('sent', 'VBD'), 'nsubj', ('emperors', 'NNS')),
#  (('emperors', 'NNS'), 'det', ('The', 'DT')),
#  (('emperors', 'NNS'), 'compound', ('Ming', 'NNP')),
#  (('sent', 'VBD'), 'obj', ('invitations', 'NNS')),
#  (('sent', 'VBD'), 'obl', ('lamas', 'NNS')),
#  (('lamas', 'NNS'), 'case', ('to', 'IN')),
#  (('lamas', 'NNS'), 'amod', ('ruling', 'VBG')),
#  (('sent', 'VBD'), 'punct', (',', ',')),
#  (('sent', 'VBD'), 'conj', ('sent', 'VBD')),
#  (('sent', 'VBD'), 'cc', ('but', 'CC')),
#  (('sent', 'VBD'), 'nsubj', ('lamas', 'NNS')),
#  (('lamas', 'NNS'), 'det', ('the', 'DT')),
#  (('sent', 'VBD'), 'obj', ('subordinates', 'NNS')),
#  (('sent', 'VBD'), 'conj', ('coming', 'VBG')),
#  (('coming', 'VBG'), 'cc', ('rather', 'RB')),
#  (('rather', 'RB'), 'fixed', ('than', 'IN')),
#  (('coming', 'VBG'), 'obj', ('themselves', 'PRP')),
#  (('sent', 'VBD'), 'punct', (',', ',')),
#  (('sent', 'VBD'), 'conj', ('accepted', 'VBD')),
#  (('accepted', 'VBD'), 'cc', ('and', 'CC')),
#  (('accepted', 'VBD'), 'nsubj', ('ruler', 'NN')),
#  (('ruler', 'NN'), 'det', ('no', 'DT')),
#  (('ruler', 'NN'), 'amod', ('Tibetan', 'JJ')),
#  (('accepted', 'VBD'), 'advmod', ('explicitly', 'RB')),
#  (('explicitly', 'RB'), 'advmod', ('ever', 'RB')),
#  (('accepted', 'VBD'), 'obj', ('role', 'NN')),
#  (('role', 'NN'), 'det', ('the', 'DT')),
#  (('role', 'NN'), 'acl', ('vassal', 'NN')),
#  (('vassal', 'NN'), 'mark', ('of', 'IN')),
#  (('vassal', 'NN'), 'cop', ('being', 'VBG')),
#  (('vassal', 'NN'), 'det', ('a', 'DT')),
#  (('vassal', 'NN'), 'nmod', ('Ming', 'NNP')),
#  (('Ming', 'NNP'), 'case', ('of', 'IN')),
#  (('Ming', 'NNP'), 'det', ('the', 'DT')),
#  (('sent', 'VBD'), 'punct', ('.', '.'))]
#
# ------SENTENCE------
# Hans Bielenstein writes that as far back as the Han dynasty (202 BCE–220 CE), the Han Chinese government "maintained the fiction" that the foreign officials administering the various "Dependent States" and oasis city-states of the Western Regions (composed of the Tarim Basin and oasis of Turpan) were true Han representatives due to the Han government's conferral of Chinese seals and seal cords to them.
#
# Word Tokenization : Done
# ['hans', 'bielenstein', 'writes', 'far', 'back', 'han', 'dynasty', '202', 'bce–220', 'ce', 'han', 'chinese', 'government', '``', 'maintained', 'fiction', "''", 'foreign', 'officials', 'administering', 'various', '``', 'dependent', 'states', "''", 'oasis', 'city-states', 'western', 'regions', 'composed', 'tarim', 'basin', 'oasis', 'turpan', 'true', 'han', 'representatives', 'due', 'han', 'government', "'s", 'conferral', 'chinese', 'seals', 'seal', 'cords']
#
# POS Tagging : Done
# [('hans', 'NNS'), ('bielenstein', 'VBP'), ('writes', 'VBZ'), ('far', 'RB'), ('back', 'RB'), ('han', 'JJ'), ('dynasty', 'NN'), ('202', 'CD'), ('bce–220', 'NN'), ('ce', 'NN'), ('han', 'NN'), ('chinese', 'JJ'), ('government', 'NN'), ('``', '``'), ('maintained', 'VBD'), ('fiction', 'NN'), ("''", "''"), ('foreign', 'JJ'), ('officials', 'NNS'), ('administering', 'VBG'), ('various', 'JJ'), ('``', '``'), ('dependent', 'JJ'), ('states', 'NNS'), ("''", "''"), ('oasis', 'VBP'), ('city-states', 'NNS'), ('western', 'JJ'), ('regions', 'NNS'), ('composed', 'VBD'), ('tarim', 'JJ'), ('basin', 'NN'), ('oasis', 'NN'), ('turpan', 'NN'), ('true', 'JJ'), ('han', 'NN'), ('representatives', 'NNS'), ('due', 'JJ'), ('han', 'JJ'), ('government', 'NN'), ("'s", 'POS'), ('conferral', 'JJ'), ('chinese', 'JJ'), ('seals', 'NNS'), ('seal', 'VBP'), ('cords', 'NNS')]
#
# Word Lemmatization : Done
# ['han', 'bielenstein', 'writes', 'far', 'back', 'han', 'dynasty', '202', 'bce–220', 'ce', 'han', 'chinese', 'government', '``', 'maintained', 'fiction', "''", 'foreign', 'official', 'administering', 'various', '``', 'dependent', 'state', "''", 'oasis', 'city-state', 'western', 'region', 'composed', 'tarim', 'basin', 'oasis', 'turpan', 'true', 'han', 'representative', 'due', 'han', 'government', "'s", 'conferral', 'chinese', 'seal', 'seal', 'cord']
#
# WordNet Feature Extraction : Done
#
# Synonyms
# ['Han', 'bielenstein', 'write', 'far', 'binding', 'Han', 'dynasty', '202', 'bce–220', 'cerium', 'Han', 'Chinese', 'government', '``', 'keep', 'fiction', "''", 'foreign', 'official', 'distribute', 'versatile', '``', 'dependent', 'state', "''", 'oasis', 'city_state', 'western', 'region', 'write', 'tarim', 'washbasin', 'oasis', 'turpan', 'true', 'Han', 'representative', 'due', 'Han', 'government', "'s", 'bestowal', 'Chinese', 'sealing_wax', 'sealing_wax', 'cord']
#
# Holonyms
# ['book', 'desert', 'desert']
#
# Meronyms
# []
#
# Hyponyms
# ['half_binding', 'Bourbon', 'Boxer', 'conserve', 'dystopia', 'football_official', 'assign', 'annotate', 'agent', 'Boxer']
#
# Hypernyms
# ['dynasty', 'create_by_mental_act', 'protective_covering', 'dynasty', 'family', 'metallic_element', 'dynasty', 'Asian', 'system', 'literary_composition', 'adjudicator', 'give', 'emotional_state', 'tract', 'state', 'sandwich', 'knowledge_domain', 'create_verbally', 'sink', 'tract', 'dynasty', 'negotiator', 'fixed_charge', 'dynasty', 'system', 'giving', 'Asian', 'fastener', 'fastener', 'tie']
#
# Dependency Parsing : Done
# [(('writes', 'VBZ'), 'nsubj', ('Bielenstein', 'NNP')),
#  (('Bielenstein', 'NNP'), 'compound', ('Hans', 'NNP')),
#  (('writes', 'VBZ'), 'ccomp', ('maintained', 'VBD')),
#  (('maintained', 'VBD'), 'mark', ('that', 'IN')),
#  (('maintained', 'VBD'), 'advmod', ('far', 'RB')),
#  (('far', 'RB'), 'advmod', ('as', 'RB')),
#  (('maintained', 'VBD'), 'advmod', ('back', 'RB')),
#  (('maintained', 'VBD'), 'obl', ('dynasty', 'NN')),
#  (('dynasty', 'NN'), 'case', ('as', 'IN')),
#  (('dynasty', 'NN'), 'det', ('the', 'DT')),
#  (('dynasty', 'NN'), 'compound', ('Han', 'NNP')),
#  (('dynasty', 'NN'), 'punct', ('(', '-LRB-')),
#  (('dynasty', 'NN'), 'dep', ('BCE', 'NNP')),
#  (('BCE', 'NNP'), 'nummod', ('202', 'CD')),
#  (('BCE', 'NNP'), 'dep', ('–', 'SYM')),
#  (('BCE', 'NNP'), 'dep', ('CE', 'NN')),
#  (('CE', 'NN'), 'nummod', ('220', 'CD')),
#  (('dynasty', 'NN'), 'punct', (')', '-RRB-')),
#  (('dynasty', 'NN'), 'punct', (',', ',')),
#  (('maintained', 'VBD'), 'nsubj', ('government', 'NN')),
#  (('government', 'NN'), 'det', ('the', 'DT')),
#  (('government', 'NN'), 'compound', ('Chinese', 'NNP')),
#  (('Chinese', 'NNP'), 'compound', ('Han', 'NNP')),
#  (('maintained', 'VBD'), 'punct', ('"', '``')),
#  (('maintained', 'VBD'), 'obj', ('fiction', 'NN')),
#  (('fiction', 'NN'), 'det', ('the', 'DT')),
#  (('fiction', 'NN'), 'punct', ('"', "''")),
#  (('fiction', 'NN'), 'ccomp', ('representatives', 'NNS')),
#  (('representatives', 'NNS'), 'dep', ('that', 'WDT')),
#  (('representatives', 'NNS'), 'nsubj', ('officials', 'NNS')),
#  (('officials', 'NNS'), 'det', ('the', 'DT')),
#  (('officials', 'NNS'), 'amod', ('foreign', 'JJ')),
#  (('officials', 'NNS'), 'acl', ('administering', 'VBG')),
#  (('administering', 'VBG'), 'obj', ('States', 'NNP')),
#  (('States', 'NNP'), 'det', ('the', 'DT')),
#  (('States', 'NNP'), 'amod', ('various', 'JJ')),
#  (('States', 'NNP'), 'punct', ('"', '``')),
#  (('States', 'NNP'), 'compound', ('Dependent', 'NNP')),
#  (('officials', 'NNS'), 'punct', ('"', "''")),
#  (('officials', 'NNS'), 'conj', ('states', 'NNS')),
#  (('states', 'NNS'), 'cc', ('and', 'CC')),
#  (('states', 'NNS'), 'compound', ('oasis', 'NN')),
#  (('states', 'NNS'), 'compound', ('city', 'NN')),
#  (('states', 'NNS'), 'punct', ('-', 'HYPH')),
#  (('states', 'NNS'), 'nmod', ('Regions', 'NNS')),
#  (('Regions', 'NNS'), 'case', ('of', 'IN')),
#  (('Regions', 'NNS'), 'det', ('the', 'DT')),
#  (('Regions', 'NNS'), 'amod', ('Western', 'JJ')),
#  (('officials', 'NNS'), 'dep', ('composed', 'VBN')),
#  (('composed', 'VBN'), 'punct', ('(', '-LRB-')),
#  (('composed', 'VBN'), 'obl', ('Basin', 'NNP')),
#  (('Basin', 'NNP'), 'case', ('of', 'IN')),
#  (('Basin', 'NNP'), 'det', ('the', 'DT')),
#  (('Basin', 'NNP'), 'compound', ('Tarim', 'NNP')),
#  (('Basin', 'NNP'), 'conj', ('oasis', 'NN')),
#  (('oasis', 'NN'), 'cc', ('and', 'CC')),
#  (('Basin', 'NNP'), 'nmod', ('Turpan', 'NNP')),
#  (('Turpan', 'NNP'), 'case', ('of', 'IN')),
#  (('composed', 'VBN'), 'punct', (')', '-RRB-')),
#  (('representatives', 'NNS'), 'cop', ('were', 'VBD')),
#  (('representatives', 'NNS'), 'amod', ('true', 'JJ')),
#  (('representatives', 'NNS'), 'compound', ('Han', 'NNP')),
#  (('representatives', 'NNS'), 'nmod', ('conferral', 'NN')),
#  (('conferral', 'NN'), 'case', ('due', 'IN')),
#  (('due', 'IN'), 'fixed', ('to', 'IN')),
#  (('conferral', 'NN'), 'nmod:poss', ('government', 'NN')),
#  (('government', 'NN'), 'det', ('the', 'DT')),
#  (('government', 'NN'), 'compound', ('Han', 'NNP')),
#  (('government', 'NN'), 'case', ("'s", 'POS')),
#  (('conferral', 'NN'), 'nmod', ('seals', 'NNS')),
#  (('seals', 'NNS'), 'case', ('of', 'IN')),
#  (('seals', 'NNS'), 'amod', ('Chinese', 'JJ')),
#  (('seals', 'NNS'), 'conj', ('cords', 'NNS')),
#  (('cords', 'NNS'), 'cc', ('and', 'CC')),
#  (('cords', 'NNS'), 'compound', ('seal', 'NN')),
#  (('conferral', 'NN'), 'nmod', ('them', 'PRP')),
#  (('them', 'PRP'), 'case', ('to', 'IN')),
#  (('writes', 'VBZ'), 'punct', ('.', '.'))]
# Completed processing the sample file
#
# Sample Task 1 Successfully Completed !!!
